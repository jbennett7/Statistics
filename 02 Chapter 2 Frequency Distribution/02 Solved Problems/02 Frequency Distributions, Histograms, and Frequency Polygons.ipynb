# %% [markdown]
# # Frequency Distributions, Histograms, and Frequency Polygons

# %% [markdown]
# ## Problem 2-3
# [Table 2.6](#Table-2-6) shows a frequency distribution of the weekly wages of 65 employees at the P&R Company. With reference to this table, determine:
# (a) The lower limit of the sixth class.
# (b) The upper limit of the fourth class.
# (c) The class mark (or class midpoint) of the third class.
# (d) The class boundaries of the fifth class.
# (e) The size of the fifth-class interval.
# (f) The frequency of the third class.
# (g) The relative frequency of the third class.
# (h) The class interval having the largest frequency. This is sometimes called the _modal class interval_; its frequency is then called the _modal class frequency_.
# (i) The percentage of employees earning less that $\$280.00$ per week.
# (j) The percentage of employees earning less than $\$300.00$ per week but at least $\$260.00$ per week.

# %% [markdown]
# #### Table 2-6

# %%
load("../../Saves/Table_2.6.Rdata")
Table.2.6
# Out:
#                 [,1]
# $250.00-$259.99  8
# 260.00-269.99   10
# 270.00-279.99   16
# 280.00-289.99   14
# 290.00-299.99   10
# 300.00-309.99    5
# 310.00-319.99    2

# %% [markdown]
# ### Solution 2-3

# %%
cat("(a) Lower limit of the sixth class:    ", strsplit(rownames(Table.2.6)[6], "-")[[1]][1], "\n")
cat("(b) Upper limit of the fourth class:   ", strsplit(rownames(Table.2.6)[4], "-")[[1]][2], "\n")
cat("(c) Class mark of the third class:     ", round((270.00+279.99)/2,2), "\n")
cat("(d) The class boundaries of the fifth class:   ", (290.00+289.99)/2, "-", (299.99+300.00)/2, "\n", sep="")
cat("(e) The size of the fifth-class interval:     ", (299.995 - 289.995), "\n")
cat("(f) The frequency of the third class:         ", Table.2.6[3], "\n")
cat("(g) The relative frequency of the third class: ", round(Table.2.6[3]/sum(Table.2.6)*100,1), "%\n", sep="")
cat("(h) The class interval having the largest frequency:      ", rownames(Table.2.6)[which.max(Table.2.6)], "\n")
cat("(i) The percentage of employees earning less than $280.00: ", round(sum(Table.2.6[1:3])/sum(Table.2.6)*100,1), "%\n", sep="")
cat("(j) The percentage of employees earning less than $300.00 per week but at least $260.00 per week: ", 
    round(sum(Table.2.6[2:5])/sum(Table.2.6)*100,1), "%\n", sep="")
# Out:
# (a) Lower limit of the sixth class:     300.00
# (b) Upper limit of the fourth class:    289.99
# (c) Class mark of the third class:      275
# (d) The class boundaries of the fifth class:   289.995-299.995
# (e) The size of the fifth-class interval:      10
# (f) The frequency of the third class:          16
# (g) The relative frequency of the third class: 24.6%
# (h) The class interval having the largest frequency:       270.00-279.99
# (i) The percentage of employees earning less than $280.00: 52.3%
# (j) The percentage of employees earning less than $300.00 per week but at least $260.00 per week: 76.9%

# %% [markdown]
# ---

# %% [markdown]
# ## Problem 2-4
# If the class marks in a frequency distribution of the weights of students are $128, 137, 146, 155, 164, 173,$ and $182$ pounds (lb), find (a) the class-interval size, (b) the class boundaries, and (c) the class limits, assuming that the weights were measured to the nearest pound.

# %%
cat("Class Marks: ", (p4.X <- c( 128, 137, 146, 155, 164, 173, 182)))
# Out:
# Class Marks:  128 137 146 155 164 173 182

# %% [markdown]
# ### Solution 2-4
# (a) Class-interval size = common difference between successive class markes = $137-128=146-137=etc.=9$lb.
# (b) Since the class intervals all have equal size, the class boundaries are midway between the class marks and thus have the values
#
# \begin{align}
# \frac{1}{2}(128+137), \frac{1}{2}(137+146), \ldots, \frac{1}{2}(173+182) \ \text{ or }\ 132.5, 141.5, 150.5, \ldots, 177.5\text{ lb}
# \end{align}
#
# The first class boundary is $132.5-9=123.5$ and the last class boundary is $177.5+9=186.5$, since the common class interval size is $9$lb. Thus all the class boundaries are given by
#
# \begin{align}
# 123.5; 132; 141.5; 150.5; 159.5; 168.5; 177.5; 186.5 \text{ lb}
# \end{align}
#
# (c) Since the class limits are integers, we choose them as the integers nearest to the class boundaries, namely, $123, 132, 133, 141, 142, \ldots$ Thus the first class has limits $124$&mdash;$132$, the next $133$&mdash;$141$, etc.

# %%
cat("(a) Class interval size: ", (p4.c <- diff(p4.X)[1]), "\n")
cat("(b) The class boundaries:", (p4.boundaries <- unique(sort(c(p4.X - p4.c/2, p4.X + p4.c/2)))), "\n")
p4.lower.limits <- p4.X - floor(p4.c/2);p4.upper.limits <- p4.X + floor(p4.c/2)
cat("(c) The class limits:     ")
for( i in 1:length(p4.lower.limits)) {
    if(i==length(p4.lower.limits)){
        cat(p4.lower.limits[i], "-", p4.upper.limits[i], "\n", sep="")
    } else {
        cat(p4.lower.limits[i], "-", p4.upper.limits[i], ", ", sep="")
    }
}
# Out:
# (a) Class interval size:  9
# (b) The class boundaries: 123.5 132.5 141.5 150.5 159.5 168.5 177.5 186.5
# (c) The class limits:     124-132, 133-141, 142-150, 151-159, 160-168, 169-177, 178-186

# %% [markdown]
# ---

# %% [markdown]
# ## Problem 2-5
# The time in hours spent on cell phones, per week, by $50$ college freshmen was sampled and the SPSS pulldown __"Analyze=>Descrioptive Statistics=>Frequencies"__ resulted in the output shown in [Fig. 2-11](#Figure-2-11).

# %% [markdown]
# #### Figure 2-11

# %%
p5.hours <- seq(3, 20, by=1)
p5.frequency <- c(3, 3, 5, 3, 4, 4, 3, 4, 2, 2, 3, 1, 2, 5, 2, 1, 2, 1)
p5.percent <- round(p5.frequency/sum(p5.frequency)*100, 1)
p5.cumulative.percent <- cumsum(p5.percent)
p5.table <- matrix(c(
    p5.hours,
    p5.frequency,
    p5.percent,
    p5.cumulative.percent), ncol=4)
colnames(p5.table) <- c("Hours", "Frequency", "Percent", "Cumulative Percent")
p5.table
# Out:
#       Hours Frequency Percent Cumulative Percent
#  [1,]  3    3          6        6
#  [2,]  4    3          6       12
#  [3,]  5    5         10       22
#  [4,]  6    3          6       28
#  [5,]  7    4          8       36
#  [6,]  8    4          8       44
#  [7,]  9    3          6       50
#  [8,] 10    4          8       58
#  [9,] 11    2          4       62
# [10,] 12    2          4       66
# [11,] 13    3          6       72
# [12,] 14    1          2       74
# [13,] 15    2          4       78
# [14,] 16    5         10       88
# [15,] 17    2          4       92
# [16,] 18    1          2       94
# [17,] 19    2          4       98
# [18,] 20    1          2      100

# %% [markdown]
# (a) What percent spent 15 or less hours per week on a cell phone?
# (b) What percent spent more than 10 hours per week on a cell phone?

# %% [markdown]
# ### Solution 2-5
# (a) The cumulative percent for $15$ hours is $78\%$. Thus $78\%$ spent $15$ hours or less on a cell phone per week.
# (b) The cumulative percent for $10$ hours is $58\%$. Thus $58\%$ spent $10$ hours or less on a cell phone per week. Therefore, $42\%$ spent more than $10$ hours on a cell phone per week.

# %%
cat("(a) Percent spent 15 or less hours per week on a cell phone:   ", as.vector(p5.table[p5.table[,1] == 15,4]), "%\n", sep="")
cat("(b) Percent spent more than 10 hours per week on a cell phone: ", as.vector(100 - p5.table[p5.table[,1] == 10,4]), "%\n", sep="")
# Out:
# (a) Percent spent 15 or less hours per week on a cell phone:   78%
# (b) Percent spent more than 10 hours per week on a cell phone: 42%

# %% [markdown]
# ---

# %% [markdown]
# ## Problem 2-6
# The smallest of $150$ measurements is $5.18$ in, and the largest is $7.44$ in. Determine a suitable set of (a) class intervals, (b) class boundaries, and (c) class marks that might be used in forming a frequency distribution of these measurements.

# %% [markdown]
# ### Solution 2-6
# The range is $7.44-5.18=2.26$ in. For a minimum of five class intervals, the class-interval size is $2.26/5=0.45$ approximately. Convenient choices of class-interval sizes lying between $0.11$ and $0.45$ would be $0.20, 0.30,$ or $0.40$.

# %% [markdown]
# (a) Columns I, II, III of the accompanying table show suitable class intervals, having sizes $0.20, 0.30,$ and $0.40$.
#
# | I | II | III |
# |-|-|-|
# | 5.10-5.29 | 5.10-5.39 | 5.10-5.49 |
# | 5.30-5.49 | 5.40-5.69 | 5.50-5.89 |
# | 5.50-5.69 | 5.70-5.99 | 5.90-6.29 |
# | 5.70-5.89 | 6.00-6.29 | 6.30-6.69 |
# | 5.90-6.09 | 6.30-6.59 | 6.70-7.09 |
# | 6.10-6.29 | 6.60-6.89 | 7.10-7.49 |
# | 6.30-6.49 | 6.90-7.19 | |
# | 6.50-6.69 | 7.20-7.49 | |
# | 6.70-6.89 | | |
# | 6.90-7.09 | | |
# | 7.10-7.29 | | |
# | 7.30-7.49 | | |
#
# Note that the lower limit in each first class could have been different from $5.10$; for example, if in column I we had started with $5.15$ as the lower limit, the first class interval could have been written $5.15-5.34$.

# %%
format.limits <- function(heading, lower, upper){
    cat(heading)
    for(i in 1:length(lower)){
        if(i==length(lower)){
            cat(lower[i], "-", upper[i], "\n", sep="")
        } else {
            cat(lower[i], "-", upper[i], ", ", sep="")
        }
    }
}

# %%
print("Class Limits")
format.limits("I:   ", (p6.ci.ll.20 <- seq(5.10, 7.30, by=.2)), (p6.ci.ul.20 <- seq(5.29, 7.49, by=.2)))
format.limits("II:  ", (p6.ci.ll.30 <- seq(5.10, 7.20, by=.3)), (p6.ci.ul.30 <- seq(5.39, 7.49, by=.3)))
format.limits("III: ", (p6.ci.ll.40 <- seq(5.10, 7.10, by=.4)), (p6.ci.ul.40 <- seq(5.49, 7.49, by=.4)))
# Out:
# [1] "Class Limits"
# I:   5.1-5.29, 5.3-5.49, 5.5-5.69, 5.7-5.89, 5.9-6.09, 6.1-6.29, 6.3-6.49, 6.5-6.69, 6.7-6.89, 6.9-7.09, 7.1-7.29, 7.3-7.49
# II:  5.1-5.39, 5.4-5.69, 5.7-5.99, 6-6.29, 6.3-6.59, 6.6-6.89, 6.9-7.19, 7.2-7.49
# III: 5.1-5.49, 5.5-5.89, 5.9-6.29, 6.3-6.69, 6.7-7.09, 7.1-7.49

# %% [markdown]
# (b) The class boundaries corresponding to columns I, II, and III of part (a) are given, respectively, by
#
# I:   $5.095$&ndash;$5.295, 5.295$&ndash;$5.495, 5.495$&ndash;$5.695,\ldots, 7.295$&ndash;$7.495$
#
# II:  $5.095$&ndash;$5.395, 5.395$&ndash;$5.695, 5.695$&ndash;$5.995,\ldots, 7.195$&ndash;$7.495$
#
# III: $5.095$&ndash;$5.495, 5.495$&ndash;$5.895, 5.895$&ndash;$6.295,\ldots, 7.095$&ndash;$7.495$
#
# Note that these class boundaries are suitable since they cannot coincide witht he observed measurements.

# %%
print("Class Boundaries")
format.limits("I:   ", (p6.ci.lb.20 <- seq(5.095, 7.295, by=.2)), (p6.ci.ub.20 <- seq(5.295, 7.495, by=.2)))
format.limits("II:  ", (p6.ci.lb.30 <- seq(5.095, 7.205, by=.3)), (p6.ci.ub.30 <- seq(5.395, 7.495, by=.3)))
format.limits("III: ", (p6.ci.lb.40 <- seq(5.095, 7.095, by=.4)), (p6.ci.ub.40 <- seq(5.495, 7.495, by=.4)))
# Out:
# [1] "Class Boundaries"
# I:   5.095-5.295, 5.295-5.495, 5.495-5.695, 5.695-5.895, 5.895-6.095, 6.095-6.295, 6.295-6.495, 6.495-6.695, 6.695-6.895, 6.895-7.095, 7.095-7.295, 7.295-7.495
# II:  5.095-5.395, 5.395-5.695, 5.695-5.995, 5.995-6.295, 6.295-6.595, 6.595-6.895, 6.895-7.195, 7.195-7.495
# III: 5.095-5.495, 5.495-5.895, 5.895-6.295, 6.295-6.695, 6.695-7.095, 7.095-7.495

# %% [markdown]
# (c) The class marks corresponding to columns I, II, and III of part (a) are given, repectively, by
#
# I&nbsp;&nbsp;&nbsp;$5.195, 5.395,\ldots, 7.395$&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;II&nbsp;&nbsp;&nbsp;$5.245, 5.545,\ldots, 7.345$&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;III&nbsp;&nbsp;&nbsp;$5.295, 5.695,\ldots, 7.295$
#
# These class marks have the disadvantage of not coinciding with the observed measurements.

# %%
print("Class Marks")
cat("I:   ", p6.ci.lb.20 + round(diff(p6.ci.lb.20)/2,1)[1], "\n")
cat("II:  ", p6.ci.lb.30 + round(diff(p6.ci.lb.30)/2,2)[1], "\n")
cat("III: ", p6.ci.lb.40 + round(diff(p6.ci.lb.40)/2,2)[1], "\n")
# Out:
# [1] "Class Marks"
# I:    5.195 5.395 5.595 5.795 5.995 6.195 6.395 6.595 6.795 6.995 7.195 7.395
# II:   5.245 5.545 5.845 6.145 6.445 6.745 7.045 7.345
# III:  5.295 5.695 6.095 6.495 6.895 7.295

# %% [markdown]
# ---

# %% [markdown]
# ## Problem 2-7
# In answering [Problem 2.6(a)](#problem-2-6), a student chose the class intervals $5.10$&ndash;$5.40, 5.40$&ndash;$5.70,\ldots, 6.90$&ndash;$7.20, and 7.20$&ndash;$7.50$. Was there anything wrong with this choice?

# %% [markdown]
# ### Solution 2-7
# These class intervals overlap at $5.40, 5.70,\ldots, 7.20$. Thus a measurement recorded as $5.40$, for example, could be placed in either of the first two class intervals. Some statisticians justify this cchoice by agreeing to place half of such ambiguous cases in one class and half in the other.
#
# The ambiguity is removed by writing the class intervals as $5.10$ to under $5.40$, $5.40$ to under $5.70$, etc. In this case, the class limits coincide with the class boundaries, and the class marks can coincide with the observed data.
#
# In general it is desirable to avoid overlapping class intervals whenever possible and to choose then so that the class boundaries are values not coinciding with actual observed data. For example, the class intervals for [Problem 2.6](#problem-2-6) could have been chosen as $5.095$&ndash;$5.395, 5.395$&ndash;$5.695$, etc., without ambiguity. A disadvantage of this particular choice is that the class marks do not coincide with the observed data.

# %% [markdown]
# ---

# %% [markdown]
# ## Problem 2-8
# In the following table the weights of 40 male students at State University are recorded to the nearest pound. Construct a frequency distribution.

# %%
load("../../Saves/Problem_2.8.Rdata")
cat("\t")
for(i in 1:length(P2.8.data)){
    cat(P2.8.data[i], "\t")
    if(i%%8==0){
        cat("\n\t")
    }
}
# Out:
# 	138 	164 	150 	132 	144 	125 	149 	157
# 	146 	158 	140 	147 	136 	148 	152 	144
# 	168 	126 	138 	176 	163 	119 	154 	165
# 	146 	173 	142 	147 	135 	153 	140 	135
# 	161 	145 	135 	142 	150 	156 	145 	128

# %% [markdown]
# ### Solution 2-8
# The largest weight is $176$ lb and the smallest weight is $119$ lb, so that the range is $176$&ndash;$119=57$ lb. If five class intervals are used, the calss-interval size is $57/5=11$ approximately; if $20$ class intervals are used, the class-interval size is $57/20=3$ approximately.
#
# One convenient choice for the class-interval size is $5$ lb. Also, it is convenient to choose the class marks as $120, 125, 130, 135,\ldots$ lb. Thus the class intervals can be taken as $118$&ndash;$122, 123$&ndash;$127, 128$&ndash;$132,\ldots$ With this choice the class boundaries are $117.5, 122.5, 127.5,\ldots$, which do not coincide with the observed data.
#
# The required frequency distribution is shown in [Table 2.7](#Table-2-7). The center column, called a _tally_, or _score sheet_, is used to tabulate the class frequencies from the raw data and is usually omitted in the final presentation of the frequency distribution. It is unnecessary to make an array, although if it is available it can be used in tabulating the frequencies.

# %% [markdown]
# #### Table 2-7

# %%
table(cut(P2.8.data,breaks=seq(118, 178, by=5), right=FALSE))
# Out:
# [118,123) [123,128) [128,133) [133,138) [138,143) [143,148) [148,153) [153,158)
#         1         2         2         4         6         8         5         4
# [158,163) [163,168) [168,173) [173,178)
#         2         3         1         2

# %% [markdown]
# #### Another method 2-8
# Of course, other possible frequency distributions exist. [Table 2.8](#Table-2-8), for example, shows a frequency distribution with only seven classes in which the class interval is $9$ lb.

# %% [markdown]
# #### Table 2-8

# %%
table(cut(P2.8.data, breaks=seq(118, 181, by=9), right=FALSE))
# Out:
# [118,127) [127,136) [136,145) [145,154) [154,163) [163,172) [172,181)
#         3         5         9        12         5         4         2

# %% [markdown]
# ---

# %% [markdown]
# ## Problem 2-9
# In the following, the heights of $45$ female students at Midwestern University are recorded to the nearest inch. Use the statistical package, STATISTIX, to construct a histogram.

# %%
p9.data <- c( 67, 67, 64, 64, 74, 61, 68, 71, 69, 61, 65, 64, 62, 63, 59,
              70, 66, 66, 63, 59, 64, 67, 70, 65, 66, 66, 56, 65, 67, 69,
              64, 67, 68, 67, 67, 65, 74, 64, 62, 68, 65, 65, 65, 66, 67)

# %% [markdown]
# ### Solution 2-9
# After entering the data into the STATISTIX worksheet, the STATISTIX pulldown __"Statistics=>Summary Statistics=>Histogram"__ produces the histogram of female heights shown in [Fig. 2-12](#Figure-2-12).

# %% [markdown]
# #### Figure 2-12

# %%
p9.h <- hist(p9.data,breaks=seq(55, 75, by=4))
# Out:
# Plot with title “Histogram of p9.data”

# %% [markdown]
# ---

# %% [markdown]
# ## Problem 2-10
# [Table 2.9](#Table-2-9) gives the one-way commuting distances for $50$ Metropolitan College students in miles.
#
# The SPSS histogram for the commuting distances in Table 2.9 is shown in Fig. 2-13. Note that the classes are $0$ to $2, 2$ to $4, 4$ to $6, 6$ to $8, 8$ to $10, 10$ to $12, 12$ to $14,$ and $14$ to $16$. The frequencies are $7, 13, 11, 7, 6, 3, 2,$ and $1$. A number is counted in the class if it falls on the lower class limit but in the next class if it falls on the upper class limit.

# %% [markdown]
# #### Table 2-9

# %%
load("../../Saves/Table_2.9.Rdata")
cat("\t")
for(i in 1:length(Table.2.9)){
    cat(Table.2.9[i], "\t")
    if(i%%10==0){
        cat("\n\t")
    }
}
# Out:
# 	4.3 	7 	8 	3.9 	3.7 	8.4 	2.6 	1 	15.7 	3.9
# 	6.5 	8.7 	0.9 	0.9 	12.6 	4 	10.3 	10 	6.2 	1.1
# 	7.2 	8.8 	7.8 	4.9 	2 	3 	4.2 	3.3 	4.8 	4.4
# 	7.7 	2.4 	8 	8 	4.6 	1.4 	2.2 	1.9 	3.2 	4.8
# 	5 	10.3 	12.3 	3.8 	3.8 	6.6 	2 	1.6 	4.4 	4.3

# %% [markdown]
# #### Figure 2-13

# %%
p10.h <- hist(Table.2.9, breaks=seq(0, 16, by=2), right=FALSE)
# Out:
# Plot with title “Histogram of Table.2.9”

# %% [markdown]
# (a) What data values are in the first class?
# (b) What data values are in the second class?
# (c) What data values are in the third class?
# (d) What data values are in the fourth class?
# (e) What data values are in the fifth class?
# (f) What data values are in the sixth class?
# (g) What data values are in the seventh class?
# (h) What data values are in the eighth class?

# %%
cat("(a) First class data values:   ", sort(Table.2.9[Table.2.9 < p10.h$breaks[2]]), "\n")
cat("(b) Second class data values:  ", sort(Table.2.9[Table.2.9 >= p10.h$breaks[2] & Table.2.9 < p10.h$breaks[3]]), "\n")
cat("(c) Third class data values:   ", sort(Table.2.9[Table.2.9 >= p10.h$breaks[3] & Table.2.9 < p10.h$breaks[4]]), "\n")
cat("(d) Fourth class data values:  ", sort(Table.2.9[Table.2.9 >= p10.h$breaks[4] & Table.2.9 < p10.h$breaks[5]]), "\n")
cat("(e) Fifth class data values:   ", sort(Table.2.9[Table.2.9 >= p10.h$breaks[5] & Table.2.9 < p10.h$breaks[6]]), "\n")
cat("(f) Sixth class data values:   ", sort(Table.2.9[Table.2.9 >= p10.h$breaks[6] & Table.2.9 < p10.h$breaks[7]]), "\n")
cat("(g) Seventh class data values: ", sort(Table.2.9[Table.2.9 >= p10.h$breaks[7] & Table.2.9 < p10.h$breaks[8]]), "\n")
cat("(h) Eighth class data values:  ", sort(Table.2.9[Table.2.9 >= p10.h$breaks[8] & Table.2.9 < p10.h$breaks[9]]), "\n")
# Out:
# (a) First class data values:    0.9 0.9 1 1.1 1.4 1.6 1.9
# (b) Second class data values:   2 2 2.2 2.4 2.6 3 3.2 3.3 3.7 3.8 3.8 3.9 3.9
# (c) Third class data values:    4 4.2 4.3 4.3 4.4 4.4 4.6 4.8 4.8 4.9 5
# (d) Fourth class data values:   6.2 6.5 6.6 7 7.2 7.7 7.8
# (e) Fifth class data values:    8 8 8 8.4 8.7 8.8
# (f) Sixth class data values:    10 10.3 10.3
# (g) Seventh class data values:  12.3 12.6
# (h) Eighth class data values:   15.7

# %% [markdown]
# ---

# %% [markdown]
# <a id="Problem-2-11"></a>
# __2.11__ The SAS histogram for the commuting distances in [Table 2.9](#Table-2-9) is shown in [Fig. 2-14](#Figure-2-14). The midpoints of the class intervals are shown. The classes are $0$ to $2.5, 2.5$ to $5.0, 5.0$ to $7.5, 7.5$ to $10.0, 10.0$ to $12.5, 12.5$ to $15.0, 15.0$ to $17.5, 17.5$, and $17.5$ to $20.0$. A number is counted in the class if it falls on the lower class limit but in the next class if it falls on the upper class limit.
# (a) What data values (in [Table 2.9](#Table-2-9)) are in the first class?
# (b) What data values are in the second class?
# (c) What data values are in the third class?
# (d) What data values are in the fourth class?
# (e) What data values are in the fifth class?
# (f) What data values are in the sixth class?
# (g) What data values are in the seventh class?

# %% [markdown]
# #### Figure 2-14

# %%
load("../../Saves/Table_2.9.Rdata")
p11.h <- hist(Table.2.9, breaks=seq(0, 20, by=2.5), right=FALSE)
# Out:
# Plot with title “Histogram of Table.2.9”

# %%
cat("(a) First class data values:   ", sort(Table.2.9[Table.2.9 < p10.h$breaks[2]]), "\n")
cat("(b) Second class data values:  ", sort(Table.2.9[Table.2.9 >= p11.h$breaks[2] & Table.2.9 < p11.h$breaks[3]]), "\n")
cat("(c) Third class data values:   ", sort(Table.2.9[Table.2.9 >= p11.h$breaks[3] & Table.2.9 < p11.h$breaks[4]]), "\n")
cat("(d) Fourth class data values:  ", sort(Table.2.9[Table.2.9 >= p11.h$breaks[4] & Table.2.9 < p11.h$breaks[5]]), "\n")
cat("(e) Fifth class data values:   ", sort(Table.2.9[Table.2.9 >= p11.h$breaks[5] & Table.2.9 < p11.h$breaks[6]]), "\n")
cat("(f) Sixth class data values:   ", sort(Table.2.9[Table.2.9 >= p11.h$breaks[6] & Table.2.9 < p11.h$breaks[7]]), "\n")
cat("(g) Seventh class data values: ", sort(Table.2.9[Table.2.9 >= p11.h$breaks[7] & Table.2.9 < p11.h$breaks[8]]), "\n")
# Out:
# (a) First class data values:    0.9 0.9 1 1.1 1.4 1.6 1.9
# (b) Second class data values:   2.6 3 3.2 3.3 3.7 3.8 3.8 3.9 3.9 4 4.2 4.3 4.3 4.4 4.4 4.6 4.8 4.8 4.9
# (c) Third class data values:    5 6.2 6.5 6.6 7 7.2
# (d) Fourth class data values:   7.7 7.8 8 8 8 8.4 8.7 8.8
# (e) Fifth class data values:    10 10.3 10.3 12.3
# (f) Sixth class data values:    12.6
# (g) Seventh class data values:  15.7

# %% [markdown]
# ---

# %% [markdown]
# ## Problem 2-12
# At the P&R Company ([Problem 2.3](#Problem-2-3)), five new employees were hired at weekly wages of $\$285.34, \$316.83, \$335.78, \$356.21,$ and $\$374.50$. Construct a frequency distribution of wages for the $70$ employees.

# %% [markdown]
# ### Solution 2-12
# Possible frequency distributions are shown in [Table 2.10](#Table-2-10).
#
# In [Table 2.10(a)](#Table-2-10-a), the same class-interval size, $\$10.00$, has been maintained throughout the table. As a result, there are too many empty classes and the detail is much too fine at the upper end of the wage scale.
#
# In [Table 2.10(b)](#Table-2-10-b), empty classes and fine detail have been avoided by the use of the open class interval "$\$320.00$ and over." A disadvantae of this is that the table becomes useless in performing certain mathematical calculations. For example, it is impossible to determine the total maount of wages paid per week, since "over $\$320.00$" might conceiveably imply that individuals could earn as high as $\$1400.00$ per week.
#
# In [Table 2.10(c)](#Table-2-10-c), a class-interval size of $\$20.00$ has been used. A disadvantage is that much information is lost at the lower end of the wage scale and the detail is still fine at the upper end of the scale.
#
# In [Table 2.10(d)](#Table-2-10-d), unequal class-interval sizes have been used. A disadvantage is that certain mathematical calculations to be made later lose a simplicity that is available when class intervals have the same size. Also, the larger the class-interval size, the greater will be the grouping error.

# %%
load("../../Saves/Table_2.6.Rdata")
Table.2.6[4] <- Table.2.6[4]+1
Table.2.6[7] <- Table.2.6[7]+1

# %% [markdown]
# #### Table 2-10

# %% [markdown]
# <a id="Table-2-10-a"></a>
# ##### Table 2-10(a)

# %%
Table.2.10.a <- matrix(c(as.vector(Table.2.6),0,1,0,1,0,1), nrow=length(Table.2.6)+6)
rownames(Table.2.10.a) <- c(rownames(Table.2.6), "320.00-329.99", "330.00-339.99", "340.00-349.99", "350.00-359.99", "360.00-369.99", "370.00-379.99")
Table.2.10.a
# Out:
#                 [,1]
# $250.00-$259.99  8
# 260.00-269.99   10
# 270.00-279.99   16
# 280.00-289.99   15
# 290.00-299.99   10
# 300.00-309.99    5
# 310.00-319.99    3
# 320.00-329.99    0
# 330.00-339.99    1
# 340.00-349.99    0
# 350.00-359.99    1
# 360.00-369.99    0
# 370.00-379.99    1

# %% [markdown]
# <a id="Table-2-10-b"></a>
# ##### Table 2.10(b)

# %%
Table.2.10.b <- matrix(c(as.vector(Table.2.6),3))
rownames(Table.2.10.b) <- c(rownames(Table.2.6), "320 and over")
Table.2.10.b
# Out:
#                 [,1]
# $250.00-$259.99  8
# 260.00-269.99   10
# 270.00-279.99   16
# 280.00-289.99   15
# 290.00-299.99   10
# 300.00-309.99    5
# 310.00-319.99    3
# 320 and over     3

# %% [markdown]
# <a id="Table-2-10-c"></a>
# ##### Table 2.10(c)

# %%
Table.2.10.c <- matrix(c(18, 31, 15, 3, 1, 1, 1), nrow=7)
rownames(Table.2.10.c) <- c("250.00-269.99", "270.00-289.99", "290.00-309.99", "310.00-329.99", "330.00-349.99", "350.00-369.99", "370.00-389.99")
Table.2.10.c
# Out:
#               [,1]
# 250.00-269.99 18
# 270.00-289.99 31
# 290.00-309.99 15
# 310.00-329.99  3
# 330.00-349.99  1
# 350.00-369.99  1
# 370.00-389.99  1

# %% [markdown]
# <a id="Table-2-10-d"></a>
# ##### Table 2.10(d)

# %%
Table.2.10.d <- matrix(c(as.vector(Table.2.6)[1:5], 8, 3))
rownames(Table.2.10.d) <- c(rownames(Table.2.6)[1:5], "300.00-319.99", "320.00-379.99")
Table.2.10.d
# Out:
#                 [,1]
# $250.00-$259.99  8
# 260.00-269.99   10
# 270.00-279.99   16
# 280.00-289.99   15
# 290.00-299.99   10
# 300.00-319.99    8
# 320.00-379.99    3

# %% [markdown]
# ---

# %% [markdown]
# ## Problem 2-13
# The EXCEL histogram for the commuting distances in [Table 2.9](#Table-2-9) is shown in [Fig. 2-15](#Figure-2-15). The classes are $0$ to $3, 3$ to $6, 6$ to $9, 9$ to $12, 12$ to $15,$ and $15$ to $18$. A number is counted in the class if it falls on the upper class limit but in the prior class if it falls on the lower class limit.

# %% [markdown]
# #### Figure 2-15

# %%
load("../../Saves/Table_2.9.Rdata")
p13.h<-hist(Table.2.9, breaks=seq(0, 18, by=3), right=TRUE)
# Out:
# Plot with title “Histogram of Table.2.9”

# %%
cat("(a) First class data values:   ", sort(Table.2.9[Table.2.9 < p10.h$breaks[2]]), "\n")
cat("(b) Second class data values:  ", sort(Table.2.9[Table.2.9 >= p13.h$breaks[2] & Table.2.9 < p13.h$breaks[3]]), "\n")
cat("(c) Third class data values:   ", sort(Table.2.9[Table.2.9 >= p13.h$breaks[3] & Table.2.9 < p13.h$breaks[4]]), "\n")
cat("(d) Fourth class data values:  ", sort(Table.2.9[Table.2.9 >= p13.h$breaks[4] & Table.2.9 < p13.h$breaks[5]]), "\n")
cat("(e) Fifth class data values:   ", sort(Table.2.9[Table.2.9 >= p13.h$breaks[5] & Table.2.9 < p13.h$breaks[6]]), "\n")
cat("(f) Sixth class data values:   ", sort(Table.2.9[Table.2.9 >= p13.h$breaks[6] & Table.2.9 < p13.h$breaks[7]]), "\n")
# Out:
# (a) First class data values:    0.9 0.9 1 1.1 1.4 1.6 1.9
# (b) Second class data values:   3 3.2 3.3 3.7 3.8 3.8 3.9 3.9 4 4.2 4.3 4.3 4.4 4.4 4.6 4.8 4.8 4.9 5
# (c) Third class data values:    6.2 6.5 6.6 7 7.2 7.7 7.8 8 8 8 8.4 8.7 8.8
# (d) Fourth class data values:   10 10.3 10.3
# (e) Fifth class data values:    12.3 12.6
# (f) Sixth class data values:    15.7

# %% [markdown]
# ---
