# %% [markdown]
# # The Range

# %% [markdown]
# ---

# %% [markdown]
# __4.1.__ Find the range of the sets (a) 12, 6, 7, 3, 15, 10, 18, 5 and (b) 9, 3, 8, 8, 9, 8, 9, 18.

# %% [markdown]
# ### Solution
# In both cases, range $=$ largest number $-$ smallest number $=18-3=15$. However, as seen from the arrays of sets (a) and (b),
#
# \begin{align*}
# \text{(a)}\ 3, 5, 6, 7, 10, 12, 15, 18\ \ \ \ \ \ \ \ \text{(b)}\ 3, 8, 8, 9, 9, 9, 18
# \end{align*}
#
# there is much more variation or dispersion, in (a) than in (b). In fact, (b) consists mainly of $8$'s and $9$'s.
# Since the range indicates no difference between the sets, it is not a very good measure of dpsersion in this case. Where extreme values are present, the range is generally a poor measure of dispersion.
# An improvement is achieved by throwing out the extreme cases, $3$, and $18$. Then for set (a) the range is $(15 - 5) = 10$, while for set (b) the range is $(9-8)=1$, clearly showing that (a) has greater dispersion than (b). However, this is not the way the range is defined. The semi-interquartile range and the 10&mdash;90 percentile range were designed to improve on the range by eliminating extreme cases.

# %%
p1.a <- c(12, 6, 7, 3, 15, 10, 18, 5)
p1.b <- c(9, 3, 8, 8, 9, 8, 9, 18)
(p1.a.range <- diff(range(p1.a)))
(p1.b.range <- diff(range(p1.b)))
# Out:
# [1] 15
# [1] 15

# %% [markdown]
# ---

# %% [markdown]
# __4.2.__ Find the range of heights of the students at XYZ University.

# %%
load("../../Saves/Table_2.1.Rdata")
Table_2.1
# Out:
#       [,1]
# 60-62  5
# 63-65 18
# 66-68 42
# 69-71 27
# 72-74  8

# %% [markdown]
# ### Solution
# There are two ways of defining the range for grouped data.
# #### First method
#
# \begin{align*}
# \text{Range}=\text{class mark of highest class}-\text{class mark of lowest class}=73-61=12\text{in}
# \end{align*}
#
# #### Second method
#
# \begin{align*}
# \text{Range}=\text{upper class boundary of highest class}-\text{lower class boundary of lowest class}=74.5-59.5=15\text{in}
# \end{align*}
#
# The first method tends to eliminate extreme cases to some extent.

# %%
# First method - use class marks
# This method tends to eliminate extreme cases to some extent
p2.marks <- c(61, 64, 67, 70, 73)
(p2.xyz.mark.range <- diff(range(p2.marks)))
# Out:
# [1] 12

# %%
# Second method - use class boundaries
p2.boundaries <- c(59.5, 62.5, 65.5, 68.5, 71.5, 74.5)
(p2.xyz.boundary.range <- diff(range(p2.boundaries)))
# Out:
# [1] 15
