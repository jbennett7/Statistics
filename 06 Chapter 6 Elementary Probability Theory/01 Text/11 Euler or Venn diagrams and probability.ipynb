# %% [markdown]
# # Euler or Venn diagrams and probability
# The event $E_1+E_2$ is the set of points that are _either in $E_1$ or $E_2$ or both_, while the event $E_1E_2$ is the set of points _common to both $E_1$ and $E_2$_. Thus the probability of an event such as $E_1$ is the sum of the probabilities associated with all points contained in the set $E_1$. Similarly, the probability of $E_1+E_2$, denoted by $\text{Pr}\{E_1+E_2\}$, is the sum of the probabilities associated with all points contained in the set $E_1+E_2$. If $E_1$ and $E_2$ have no points in common (i.e., the events are mutually exclusive), then $\text{Pr}\{E_1+E_2\}=\text{Pr}\{E_1\}+\text{Pr}\{E_2\}$. If they have points in common, then $\text{Pr}\{E_1+E_2\}=\text{Pr}\{E_1\}+\text{Pr}\{E_2\}-\text{Pr}\{E_1E_2\}$.
#
# The set $E_1+E_2$ is sometimes denoted by $E_1\cup E_2$ and is called the _union_ of two sets. The set $E_1E_2$ is sometimes denoted by $E_1\cap E_2$ and is called the _intersection_ of the two sets. Extensions to more than two sets can be made; thus instead of $E_1+E_2+E_3$ and $E_1E_2E_3$, we could use the notations $E_1\cup E_2\cup E_3$ and $E_1\cap E_2\cap E_3$, respectively.
#
# The symbol $\phi$ (the Greek letter _phi_) is sometimes used to denote a set with no points in it, called the _null set_. The probability associated with an event corresponding to this set is zero (i.e., $\text{Pr}\{\phi\}=0$). If $E_1$ and $E_2$ have no points in common, we can write $E_1E_2=\phi$, which means that the corresponding events are mutually exclusive, whereby $\text{Pr}\{E_1E_2\}=0$.
#
# With this modern approach, a random variable is a function defined at each point of the sample space. For example, in Problem 6.37 the random variable is the sum of the coordintes of each point.
#
# In the case where $S$ has an infinite number of points, the above ideas can be extended by using concpets of calculus.

# %% [markdown]
# __EXAMPLE 14.__ An experiment consists of rolling a pair of dice. Event $E_1$ is the event that a $7$ occurs, i.e., the sum on the dice is $7$. Event $E_2$ is the event that an odd number occurs on die $1$. Sample space $S$, events $E_1$ and $E_2$ are shown. Find $\text{Pr}\{E_1\}$, $\text{Pr}\{E_2\}$, $\text{Pr}\{E_1\cup E_2\}$ and $\text{Pr}\{E_1\cap E_2\}$. $E_1$, $E_2$, and $S$ are shown in separate panels of the MINITAB output shown in Fig. 6-6.
#
# \begin{align}
# P(E_1) =6/36=1/6\ \ P(E_2)=18/36=1/2\ \ P(E_1\cap E_2)=3/36=1/12 \\
# P(E_1\cup E_2) =6/36+18/36-3/36=21/36
# \end{align}
