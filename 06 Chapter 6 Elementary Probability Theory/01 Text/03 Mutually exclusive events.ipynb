# %% [markdown]
# # Mutually exclusive events
# Throw or more events are called _mutually exclusive_ if the occurrence of any one of them excludes the occurrence of the others. Thus if $E_1$ and $E_2$ are mutually exclusive events, then $\text{Pr}\{E_1E_2\} =0$.
#
# If $E_1 + E_2$ denotes the event that "either $E_1$ or $E_2$ or both occur," then
#
# \begin{align}\label{eq5}\tag{5}
# \text{Pr}\{E_1+E_2\}=\text{Pr}\{E_1\}+\text{Pr}\{E_2\}-\text{Pr}\{E_1E_2\}
# \end{align}
#
# In particular,
#
# \begin{align}\label{eq6}\tag{6}
# \text{Pr}\{E_1+E_2\}=\text{Pr}\{E_1\}+\text{Pr}\{E_2\} \ \ \ \ \ \ \ \ \text{for mutually exclusive events}
# \end{align}
#
# As an extension of this, if $E_1,E_2,\ldots,E_n$ are $n$ mutually exclusive evnets having respective probabilities of occurrence $p_1,p_2,\ldots,p_n$, then the probability of occurrence of either $E_1$ or $E_2$ or $\cdots E_n$ is $p_1+p_2+\cdots+p_n$.
#
# Result (5) can also be generalized to three or more mutually exclusive events.

# %% [markdown]
# __EXAMPLE 6.__ If $E_1$ is the event "drawing an ace from a deck of cards" and $E_2$ is the event "drawing a king," then $\text{Pr}\{E_1\}=\frac{4}{52}=\frac{1}{13}$ and $\text{Pr}\{E_2\}=\frac{4}{52}=\frac{1}{13}$. The probability of drawing either an ace or a king in a single draw is
#
# \begin{align}
# \text{Pr}\{E_1+E_2\}=\text{Pr}\{E_1\}+\text{Pr}\{E_2\}=\frac{1}{13}+\frac{1}{13}=\frac{2}{13}
# \end{align}
#
# since both an ace and a king cannot be drawn in a single draw and are thus mutually exclusive events.
#
# Note that $E_1$ and $E_2$ have no outcomes in common. They are mutually exclusive.

# %% [markdown]
# __EXAMPLE 7.__ If $E_1$ is the event "drawing an ace" from a deck of cards and $E_2$ is the event "drawing a spade," then $E_1$ and $E_2$ are not mutually exclusive since the ace of spades can be drawn. Thus the probability of drawing either an ace or a spade or both is
#
# \begin{align}
# \text{Pr}\{E_1+E_2\}=\text{Pr}\{E_1\}+\text{Pr}\{E_2\}-\text{Pr}\{E_1E_2\}=
# \frac{4}{52}+\frac{13}{52}-\frac{1}{52}=\frac{16}{52}=\frac{4}{13}
# \end{align}
#
# Note that the event "$E_1$ and $E_2$" consisting of those outcomes in both events is the ace of spades.
