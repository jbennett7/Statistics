# %% [markdown]
# # Combinatorial analysis
# In obtaining probabilities of complex events, an enumeration of cases is often difficult, tedious, or both. To facilititate the labor involved, use is made of basic principles studied in a subject called _combinatorial analysis_.
#
# #### Fundamental Principle
# If an event can happen in any one of $n_1$ ways, and if when this has occurred another event can happen in any one of $n_2$ ways, then the number of ways in which both events can happen in the specified order is $n_1n_2$.

# %% [markdown]
# __EXAMPLE 10.__ The numbers $0$ through $5$ are entered into $A1$ through $A6$  in EXCEL and $=\text{FACT}(A1)$ is entered into $B1$ and a click-and-drag is performed from $B1$ through $B6$. Then the chart wizard is used to plot the points. The function $=\text{FACT}(n)$ is the same as $n!$. For $n=0,1,2,3,4,\text{ and }5, =\text{FACT}(n)$ equals $1,1,2,6,24,\text{ and }120$. FIgure 6.4 was generated by the chart wizard in EXCEL.

# %% [markdown]
# __EXAMPLE 11.__ The number of permutations of the letters $a, b$, and $c$ taken two at a time is $_3P_2=3\cdot2=6$. These are $ab, ba, ac, ca, bc, \text{ and } cb$.
#
# The number of permutations of $n$ objects consisting of groups which $n_1$ are alike, $n_2$ are alike,$\cdots$is
#
# \begin{align}\label{eq10}\tag{10}
# \frac{n!}{n_1!n_2!\cdots} \ \ \ \ \text{ where } n = n_1 + n_2 + \cdots
# \end{align}

# %% [markdown]
# __EXAMPLE 12.__ The number of permutaitons of letters in the word _statistics_ is
#
# \begin{align}
# \frac{10!}{3!3!1!2!1!}=50,400
# \end{align}
#
# since there are $3$s's, $3$t's, $1$a, $2$i's, and $1$c.
