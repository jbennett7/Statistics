# %% [markdown]
# # Review exercises

# %% [markdown]
# 1. A pair of dice are thrown.
#
# * (a) Find the chance that both dice show 3 spots.
# * (b) Find the chance that both dice show the same number of spots.
#
# _Solution._
#
# * The chance that both dice show 3 spots is $1/6 \times 1/6 = 1/36$.
# * The chance that both dice show the same number of spots is $6 \times 1/36 = 1/6$.

# %% [markdown]
# 2. In Monopoly, a player rolls two dice, counts the total number of spots, and moves that many squares. Find the chance that the player moves 11 squares (no more, no less).
#
# _Solution._
#
# There are two chances out of 36 to roll 11. The chance of rolling 11 is $2/36 = 1/18$.

# %% [markdown]
# 3. True or false, and explain:
#
# * (a) If a die is rolled three times, the chance of getting at least one ace is $1/6 + 1/6 + 1/6 = 1/2$.
# * (b) If a coin is tossed twice, the chance of getting at least one head is $100\%$.
#
# _Solution._
# * (a) False. The chance of not getting at least one ace is $5/6 \times 5/6 \times 5/6 = 15/36 = 5/12$. The chance of getting at least one ace is $12/12 - 5/12 = 7/12$.
# * (b) False. The chance of getting at least one head is $1 - (1/2 \times 1/2) = 1 - 1/4 = 3/4$.

# %% [markdown]
# 4. Two cards will be dealt off the top of a well-shuffled deck. You have a choice:
# * (i) to win $\$1$ if at least one of the two cards is a queen.
# * (ii) to win $\$1$ if the first is a queen.
# Which option is better? Or are they equivalent? Explain.
#
# _Solution._
# They are not the same. option (i) is better.
# * (i) $1 - (48/52 \times 48/52) = .15$
# * (ii) $1/52 = .019$

# %% [markdown]
# 5. The chance of A is $1/3$; the chance of B is $1/10$. True or false, and explain:
# * (a) If A and B are independent, they must be mutually exclusive.
# * (b) If A and B are mutually exclusive, they cannot be independent.
#
#
# _Solution._
# * (a) False. For A and B to be independent, the chance of B cannot be influenced by the chance of A and vice versa. However, for them to be mutually exclusive, the occurrence of one event prohibits the occurrence of the other.
# * (b) True. Because the occurrence of one of the events prohibits the occurrence of the other, they are not independent.

# %% [markdown]
# 6. One event has chance $1/2$, another has chance $1/3$. FIll in the blanks, using one phrase for each pair below, to make up two true sentences. Write out both sentences.
#
# "If you want to find the chance that \_\_(i)\_\_ will happen, check to see if they are \_\_(ii)\_\_. If so, you can \_\_(iii)\_\_ the chances."
#
# * (i) at least one of the two events, both events
# * (ii) independent, mutually exclusive
# * (iii) add, multiply
#
# _Solution._
# * (i) both events
# * (ii) mutually exclusive
# * (iii) add

# %% [markdown]
# 7. Four draws are going to be made at random with replacement from the box
#
# | 1 | 2 | 2 | 3 | 3 |
#
# Find the chance that | 2 | is drawn at least once.
#
# With replacement means that each draw is independent. The chance of getting no | 2 | on all four draws is: $(\frac{3}{5})^4 = 0.1296$.
# The chance of getting at least one | 2 | is $1 - .1296 = .8704 \approx 87\%$.

# %% [markdown]
# 8. Repeat exercise 7, if the draws are made at random without replacement.
#
# Without replacement means that the draws are not independent. But since there are only five tickets. The chance that one of them will be a | 2 | is $100\%$.

# %% [markdown]
# 9. One ticket will be drawn at random from each of the two boxes shown below:
# \begin{align*}
# \text{(A)}\text{ | 1 | 2 | 3 | }
# \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \
# \text{(B)}\text{ | 1 | 2 | 3 | 4 | }
# \end{align*}
#
# Find the chance that:
# * (a) The number drawn from A is larger than from B.
# * (b) The number drawn from A equals the one from B.
# * (c) The number drawn from A is smaller than from B.
#
# _Solution._
# * (a) The events are independent. Six Mutually exclusive events are possible; therefore, the chance is $6/12 = 1/2$.
# * (b) The events are independent. Thre are three mutually exclusive events possible; therefore the chance is $3/12 = 1/4$.
# * (c) The events are independent. Three mutually exclusive events are possible; therefore, the chance is $3/12 = 1/4$.

# %% [markdown]
# 10. There are two options:
#
# * (i) A die will be rolled 60 times. Each time it shows an ace or a six, you win $\$1$; on the other rolls, you win nothing.
# * (ii) Sixty draws will be made randomly with replacements from the box | 1 | 1 | 1 | 0 | 0 | 0 |. On each draw, you will be paid the amount shown on the ticket in dollars.
#
# Which option is better? or are they the same? Explain briefly.
#
#
# _Solution._
# There is a $2/6 = 1/3$ chance of getting an ace or a six on each roll. There is a $1/2$ chance of drawing a | 1 |. Your chances are better drawing from the box.

# %% [markdown]
# 11. Three cards are dealt from a well-shuffled deck.
#
# * (a) Find the chance that all of the cards are diamonds.
# * (b) Find the chance that none of the cards are diamonds.
# * (c) Find the chance that the cards are not all diamonds.
#
#
# _Solution._
#
# * (a) $1/52 \times 1/51 \times 1/50 = 1/132600 < 1\%$
# * (b) $49/52 \times 49/51 \times 49/50 = 117649/132600 \approx 89\%$
# * (c) $1 - 1/132600 = 132599/132600 \approx 99\%$

# %% [markdown]
# 12. A coin is tossed 10 times. True or false, and explain:
#
# * (a) The chance of getting 10 heads in a row is $1/1,024$.
# * (b) Given that the first 9 tosses were heads, the chance of getting 10 heads in a row is $1/2$.
#
# _Solution._
# * (a) True. The chance is calculated $(1/2)^10$
# * (b) True. Each event is independent therefore each toss has a $1/2$ chance of being heads.

# %% [markdown]
# 13. A box contains 2 red marbles and 98 blue ones. Draws are made at random with replacement. In \_\_\_\_ draws from the box, there is better than a $50\%$ chance for a red marble to appear at least once. Fill in the blank with the smallest number that makes the statement true. (You will need a calculator).
#
# _Solution._
# You need to find the chance that no red will be appear for each roll, until the chances fall below $50\%$.

# %%
for (x in 1:100){
    r <- (49/50)^x
    if (r < .5) {
        cat(x, r, '\n')
        break
    }
}
# Out:
# 35 0.4930746

# %% [markdown]
# 14. In Lotto 6-53, there is a box with 53 balls, numbered from 1 to 53. Six balls are drawn at random without replacement from the box. You win the grand prize if the numbers on your lottery ticket are the same as the numbers on the six balls; order does not matter.
#
# Person A bought two tickets, with the following numbers:
# Ticket #1&emsp;&emsp;5&emsp;12&emsp;21&emsp;30&emsp;42&emsp;51
# Ticket #2&emsp;&emsp;5&emsp;12&emsp;23&emsp;30&emsp;42&emsp;49
#
# Person B bought two tickets, with the following numbers:
# Ticket #1&emsp;&emsp;7&emsp;11&emsp;25&emsp;28&emsp;34&emsp;50
# Ticket #2&emsp;&emsp;9&emsp;14&emsp;20&emsp;22&emsp;37&emsp;45
#
# Which person has the better chance of winning? Or are their chances the same? Explain briefly.
#
#
# _Solution._
#
# They are the same.
