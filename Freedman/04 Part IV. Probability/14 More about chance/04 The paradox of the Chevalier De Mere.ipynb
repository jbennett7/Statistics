# %% [markdown]
# # The paradox of the Chevalier De Mere

# %% [markdown]
# If the chance of an event is hard to find, try to find the chance of the opposite event. Then subtract from $100\%$. This is useful when the chance of the opposite event is easier to compute.

# %% [markdown]
# ## Exercise Set D

# %% [markdown]
# 1. A die is rolled three times. You bet $\$1$ on some proposition. Below is a list of $6$ bets and then a list of $3$ outcomes. For each bet, find all the outcomes for which you win. For instance, with (a), you win on (i) only.
#
#
# Bets
#
# * (a) all aces
# * (b) at least one ace
# * (c) no aces
# * (d) not all aces
# * (e) 1st roll is an ace, or 2nd roll is an ace, or 3rd roll is an ace
# * (f) 1st roll is an ace, and 2d roll is an ace, and 3rd roll is an ace
#
#
# Outcomes
#
# * (i) |1|1|1|
# * (ii) |2|1|3|
# * (iii) |3|5|2|
#
#
# _Solution._
#
# * (a) i
# * (b) i, ii
# * (c) iii
# * (d) ii, iii
# * (e) i, ii
# * (f) i

# %% [markdown]
# 2. In exercise 1, which is a better bet&mdash;(a) or (f)? Or are they the same? What about (b) and (e)? What about (c) and (d)? (You do not need to compute the chances).
#
# _Solution._
# * They are both the same.
# * They are both the same.
# * Bet (d) is the better bet.

# %% [markdown]
# 3. A box contains four tickets, one marked with a star, and the other three are blank.
#
# |*| | | |
#
# Two draws are made at random with replacement from this box.
# * (a) What is the chance of getting a blank ticket on the first draw?
# * (b) What is the chance of getting a blank ticket on the second draw?
# * (c) What is the chance of getting a blank ticket on the first draw and a blank ticket on the second draw?
# * (d) What is the chance of not getting the star in the two draws?
# * (e) What is the chance of getting the star at least once in the two draws?
#
# _Solution._
# * (a) $3/4$
# * (b) $3/4$
# * (c) $3/4 \times 3/4 = 9/16$
# * (d) $3/4 \times 3/4 = 9/16$
# * (e) $1 - 9/16 = 7/16$

# %% [markdown]
# 4. (a) A die is rolled 3 times. What is the chance of getting at least one ace?
# * (b) Same, with 6 rolls.
# * (c) Same, with 12 rolls.
#
#
# _Solution._
#
# * (a) $1 - (5/6)^3$
# * (b) $1 - (5/6)^6$
# * (c) $1 - (5/6)^12$

# %% [markdown]
# 5. A pair of dice is rolled 36 times. What is the chance of getting at least one double-ace?
#
#
# _Solution._
# $1 - (35/36)^36$

# %% [markdown]
# 6. According to de Moivre, in eighteenth-century England, people played a game similar to modern roulette. It was called "Royal Oak." There were 32 "points" or numbered pockets on a table. A ball was thrown in such a way that it landed in each pocket with an equal chance, 1 in 32.
#
# If you bet 1 pound on a point and it came up, you got your stake back, together with winnings of 27 pounds. If your point didn't come up, you lost your pound. The players (or "Adventurers," as de Moivre called them) complained that the game was unfair, and they should have won 31 pounds if their point came up. (They were right; section 1 of chapter 17). De Moivre continues.
#
# The Master of the Ball maintained they had no reason to complain; since he would undertake that any particular point of the Ball should come up in Two-and-Twenty Throws: of this he would offer to lay a Wager, and actually laid it when required. The seeming contradiction between the Odds of One-and-Thirty to One, and Twenty-two Throws for any \[point\] to come up, so perplexed the Adventurers, that they begun to think the Advantage was on their side: for which reason they played on and continued to lose. \[Two-and-Twenty is 22, One-and-Thirty is 31\].
#
# What is the chance that the point $17$, say, will come up in Two-and-Twenty Throws? (The Master of the Ball laid this wager at even money, so if the chance is over $50\%$, he shows a profit here too).
#
# _Solution._
# The chance that the point 17 will not come up in 22 throws is $(31/32)^22 \approx 49.7\%$. The chance that it will come up in 22 throws is therefore $100\% - 49.7\% = 50.3\%$.

# %% [markdown]
# 7. In his novel. _Bomber_, Len Deighton argues that a World War II pilot had a $2\%$ chance of being shot down on each mission. So in 50 missions, he is "mathematically certain" to be shot down: $50 \times 2\% = 100\%$. Is this a good argument?
#
#    _Hint_: To calculate chance, you have to imagine the situation as a game of chance. The analogy here is getting the card "survive" every time if you draw 50 times at random with a replacement from the box.
#
#
# _Solution._
# So in the box there is 100 cards. Two card says "Shot Down", and 98 that say "Survive". If you draw from the box fifty times at random with replacement.
# \begin{align*}
# (1 - .02)^50 \approx .364 = 36.4\%
# \end{align*}
