# %% [markdown]
# # Introduction

# %% [markdown]
# Defining what is meant by the word _chance_ is very hard in mathematical terms. There are some carefully thought-out theories, but the theories only cover a small set of what ordinary people call chance. Freedman <sup>[\[1\]](../../../README.md#ref1)</sup> presents _frequency theory_ version. This works best for tests that can be repeated over and over again.
