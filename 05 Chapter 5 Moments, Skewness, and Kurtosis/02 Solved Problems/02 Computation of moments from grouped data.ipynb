# %% [markdown]
# # Computation of moments from grouped data

# %% [markdown]
# ## Problem 5-6
# Find the first four moments about the mean for the heigh distribution of Problem [3.22](../../03%20Chapter%203%20The%20Mean,%20Median,%20Mode,%20and%20Other%20Measures%20of%20Central%20Tendency/02%Solved%20Problems/04%20The%20arithmetic%20mean%20computed%20from%20grouped%20data.ipynb#Problem-3-22).

# %% [markdown]
# ### Solution 5-6
