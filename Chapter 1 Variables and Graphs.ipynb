# %% [markdown]
# # Chapter 1 Vairables and Graphs

# %% [markdown]
# ## Statistics

# %% [markdown]
# ## Population and sample; inductive and descriptive statistics

# %% [markdown]
# ## Variables: discrete and continuous

# %% [markdown]
# ## Rounding of data

# %% [markdown]
# ## Scientific notation

# %% [markdown]
# ## Significant figures

# %% [markdown]
# ## Computations

# %% [markdown]
# ## Functions

# %% [markdown]
# ## Rectangular coordinates

# %% [markdown]
# ## Graphs

# %% [markdown]
# ## Equations

# %% [markdown]
# ## Inequalities

# %% [markdown]
# ## Logarithms

# %% [markdown]
# ## Properties of logarithms

# %% [markdown]
# ## Logarithmic equations
