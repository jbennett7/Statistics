# %% [markdown]
# # Software and measures of central tendency
# All the software packages utilized in this book give the descriptive statistics discussed int his section. The output for all five packages is now given for the test scores in Example 17.

# %% [markdown]
# ## R programming

# %%
ex.17 <- c(
    88, 45, 53, 86, 33, 86, 85, 30, 89, 53, 41, 96, 56, 38, 62,
    71, 51, 86, 68, 29, 28, 47, 33, 37, 25, 36, 33, 94, 73, 46,
    42, 34, 79, 72, 88, 99, 82, 62, 57, 42, 28, 55, 67, 62, 60,
    96, 61, 57, 75, 93, 34, 75, 53, 32, 28, 73, 51, 69, 91, 35
)

# %%
summary(ex.17)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   25.00   37.75   57.00   59.17   76.00   99.00

# %%
mode <- function(x) {
    ux <- unique(x)
    return (ux[which.max(tabulate(match(x, ux)))])
}

# %%
mode(ex.17)
# Out:
# [1] 53

# %%
str(ex.17)
# Out:
#  num [1:60] 88 45 53 86 33 86 85 30 89 53 ...
