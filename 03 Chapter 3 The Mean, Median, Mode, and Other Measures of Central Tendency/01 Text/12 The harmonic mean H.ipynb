# %% [markdown]
# # The harmonic mean H
# The harmonic mean $H$ of a set of $N$ numbers $X_1, X_2, X_3,\ldots, X_N$ is the reciprocal of the arithmetic mean of the reciprocals of the numbers:
#
# <a id=eq12></a>
# \begin{align}\label{eq12}\tag{12}
# H=\frac{1}{\frac{1}{N}\sum^N_{j=1}{\frac{1}{X_j}}}=\frac{N}{\sum{\frac{1}{X}}}
# \end{align}
#
# In practice it may be easier to remember that
#
# <a id=eq13></a>
# \begin{align}\label{eq13}\tag{13}
# \frac{1}{H}=\frac{\sum{\frac{1}{X}}}{N}=\frac{1}{N}\sum{\frac{1}{X}}
# \end{align}
#
# __EXAMPLE 14.__ The harmonic mean of the numbers $2, 4,$ and $8$ is
#
# \begin{align}
# H=\frac{3}{\frac{1}{2}+\frac{1}{4}+\frac{1}{8}}=\frac{3}{\frac{7}{8}}=3.43
# \end{align}

# %% [markdown]
# ---

# %% [markdown]
# ## Harmonic mean in R

# %%
harmonic.mean <- function(x) {
    return(length(x)/sum(x^(-1)))
}

# %%
X <- c(2, 4, 8)
round(harmonic.mean(X), 2)
# Out:
# [1] 3.43
