# %% [markdown]
# # Quartiles, deciles, and percentiles

# %% [markdown]
# ## Problem 3.107
# Table 3.13 shows a frequency distribution of grades on a final examination in college algebra. (a) Find the quartiles of the distribution, and (b) interpret clearly the significance of each.

# %%
p3.107 <- new.env()
p3.107$grade <- c("90-100", "80-89", "70-79", "60-69", "50-59", "40-49", "30-39")
p3.107$number.of.students <- c(9,32,43,21,11,3,1)
p3.107$df <- data.frame(Grade=p3.107$grade,Studens=p3.107$number.of.students)
p3.107$df
# Out:
#   Grade  Studens
# 1 90-100  9
# 2 80-89  32
# 3 70-79  43
# 4 60-69  21
# 5 50-59  11
# 6 40-49   3
# 7 30-39   1

# %% [markdown]
# ### Solution

# %% [markdown]
# ---
