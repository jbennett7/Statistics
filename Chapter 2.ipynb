# %% [markdown]
# # Chapter 2 Frequency Distributions

# %% [markdown]
# ## Raw data
# _Raw data_ are collected data that have not been organized numerically. An example is the set of heights of $100$ maile students obtained from an alphabetical listing of university records.
#
# In R, raw data can be assembled into `vectors`, `data-frames`, or `matrices`.

# %% [markdown]
# ## Arrays
# An _array_ is an arrangement of raw numberical data in ascending or descending order of magnitude. The difference between the largest and smallest numbers is called the _range_ of the data. For example, if the largest height of $100$ male students is 74 inches (in) and the samllest height in 60 in, the range is $74 - 60 = 14$ in.
#
# The closest thing to an array in R is a `vector`. You can arrange the data in ascending or descending order using the `sort` function along with the `decreasing` boolean:

# %%
a <- c( 3, 5, 2, 4, 4, 7, 8, 5, 2, 6, 6, 9)
#decreasing=FALSE is default
sort(a)
sort(a, decreasing=TRUE)
# Out:
#  [1] 2 2 3 4 4 5 5 6 6 7 8 9
#  [1] 9 8 7 6 6 5 5 4 4 3 2 2

# %% [markdown]
# ## Frequency distributions
# When summarizing large masses of raw data, it is often useful to distribute the data into _classes_, or _categories_, and to determine the number of individuals belonging to each class, called the _class frequency_. A tabular arrangement of data by classes together with the corresponding class frequencies is called a _frequency distribution_, or _frequency table_. Table 2.1 is a freqency distribution of heights (recorded to the nearest inch) of $100$ maile students at XYZ University.
#
# The first class (or category), for example, consists of heights from $60$ to $62$ in and is indicated by the range symbol `60-62`. Since five students have heights belonging to this class, the corresponding class frequency is 5.
#
# Data organized and summarizzed as in the above frequency distribution are often called _grouped data_. Although the grouping process generally destroys much of the original detail of the data, an important advantage is gained in the clear "overall" picture that is obtained and in the vital relationships that are thereby made evident.
#
# <h5 style="text-align: center;">Table 2.1 Heights of 100 male students at XYZ University</h5>
#
# | Height (in) | Number of Students |
# |:-----------:|:------------------:|
# |    60-62    |          5         |
# |    63-65    |         18         |
# |    66-68    |         42         |
# |    69-71    |         27         |
# |    72-74    |          8         |
# |       Total |         100        |

# %% [markdown]
# ## Class intervals and class limits
# A symbol defining a class, such as `60-62` in Table 2.1, is called a _class interval_. The end numbers, $60$ and $62$, are called _class limits_; the smaller number $(60)$ is the _upper class limit_. The terms _class_ and _class interval_ are often used interchangeably, although the class interval is actually a symbol for the class.
#
# A class interval that, at least theoretically, has either no upper class limit or no lower class limit indicated is called an _open class interval_. For example, referring to age groups of individuals, the class interval "65 years and over" is an open class interval.

# %% [markdown]
# ## Class boundaries
# If heights are recorded to the nearest inch, the class interval `60-62` theoretically includes all measurements from $59.5000$ to $62.5000$ in. These numbers, indicated briefly by the exact numbers $59.5$ and $62.5$, are called _class boundaries_, or _true class limits_; the smaller number $(59.5)$ is the _lower class boundary_, and the larger number $(62.5)$ is the _upper class boundary_.
#
# In practice, the class boundaries are obtained by adding the upper limit of one class interval to the lower limit of the next-higher class interval and dividing by $2$.
#
# Sometimes, class boundaries are used to symbolize classes. For example, the various classes in the first column of Table 2.1 could be indicated by $59.4-62.5$, $62.5-65.5$, etc. To avoid ambiguity in using such notation, class boundaries should not coincide with actual observations. Thus if an observation were $62.5$, it would not be possible to decide whether it belonged to the class interval $59.5-62.5$ or $62.5-65.5$.
#
# In R, most data grouping is done using `breaks` and determining whether the right or left side of the class interval is open.

# %% [markdown]
# ## The size, or width, of a class interval
# The size, or width, of a class interval is the difference between the lower and upper class boundaries and is also referred to as the _class width_, _class size_, or _class length_. If all class intervals of a frequency distribution have equal widths, this common width is denoted by $c$. In such case $c$ is equal to the difference between two successive lower class limits or two successive upper class limtits. For the data of Table 2.1, for example, the class interval is $c = 62.5 - 59.5 = 65.5 - 62.5 = 3$.
#
# In R, you can use the difference between two successive class limit elements in either the lower class limit or upper class limit to determine the class size.

# %% [markdown]
# ## The class mark
# The _class mark_ is the midpoint of the class interval and is obtained by adding the lower and upper class limits and by dividing by $2$. Thus the class mark of the interval `60-62` is $\frac{(60+62)}{2}=61$. The class mark is also called the _class midpoint_.
#
# For purposes of further mathematical analysis, all observations belonging to a given class interval are assumed to coincide with the class mark. Thus all heights in the class interval `60-62` in are considered to be $61$ in.

# %% [markdown]
# ## General rules for forming frequency distributions
# 1. Determine the largest and smallest numbers in the raw data and thus find the range (the difference between the largest and smallest numbers).
# 2. Divide the range into a convenient number of class intervals having the same size. If this is not feasible, use class intervals of different sizes or open class intervals. The number of class intervals is usually between $5$ and $20$, depending on the data. Class intervals are also chosen so that the class marks (or midpoints) coincide with the actually observed data. This tends to lessen the so-called _grouping error_ involved in further mathematical analysis. However, the class boundaries should not coincide with the actually observed data.
# 3. Determine the number of observations falling into each class interval; that is, find the class frequencies. This is best done by using a _tally_, or _score sheet_.

# %% [markdown]
# ### How to generate a frequency table in R if you don't have the original data.

# %% [markdown]
# First lets define the upper and lower class limits:

# %%
lower.limits <- c(60, 63, 66, 69, 72)
upper.limits <- c(62, 65, 68, 71, 74)

# %% [markdown]
# The class size is found by finding the difference between the either the upper limits, or the lower limits. This can be found with R's `diff`

# %%
class.size <- diff(lower.limits)[1]

# %% [markdown]
# Then define the frequency of each class:

# %%
f <- c(5, 18, 42, 27, 8)

# %% [markdown]
# Because we do not have access to the original data that was used to create the frequency distribution table, we will need to generate a similar distribution.

# %%
s1 <- c()
for(i in 1:length(f)){
    s1 <- sample(c(s1, sample(lower.limits[i]:upper.limits[i], f[i], replace=TRUE)))
}

# %% [markdown]
# In R, we use the `cut` function to divide up the data set into classes. We define the `breaks` and whether the interval is open on the right or left using the boolean `right`. If the table is left open-interval (`right=FALSE`), then we generate breaks from the first class lower limit $60$ to $75$, one above the last class's upper-limit.

# %%
breaks <- seq(60,75,by=class.size)
table(cut(s1, breaks=breaks, right=FALSE))
# Out:
# [60,63) [63,66) [66,69) [69,72) [72,75)
#       5      18      42      27       8

# %% [markdown]
# If the table is right open-interval (`right=TRUE`), then we generate breaks from one below the first class's lower limit $(59)$ to $74$, the last class's upper limit.

# %%
breaks <- seq(59,74,by=3)
#right=TRUE is default
table(cut(s1, breaks=breaks))
# Out:
# (59,62] (62,65] (65,68] (68,71] (71,74]
#       5      18      42      27       8

# %% [markdown]
# ## Histograms and frequency polygons

# %% [markdown]
# ## Dot plots and box plots

# %% [markdown]
# ## Relative-frequency distributions

# %% [markdown]
# ## Cumulative-frequency distributions and ogives

# %% [markdown]
# ## Relative cumulative-frequency distributions and percentage ogives

# %% [markdown]
# ## Frequency curves and smoothed ogives

# %% [markdown]
# ## Types of frequency curves
