# %% [markdown]
# # Joint and conditional probability

# %% [markdown]
# ## Joint Probabilty

# %% [markdown]
# The probability $P(A \cap B)$ is called the _joint probability_ for two events $A$ and $B$ which intersect in the sample space. A study of a Venn diagram will readily show that
# \begin{align*}\tag{1.4-1}
# P(A \cap B) = P(A) + P(B) - P(A \cup B)
# \end{align*}
# Equivalently,
# \begin{align*}\tag{1.4-2}
# P(A \cap B) = P(A) + P(B) - P(A \cap B) \le P(A) + P(B)
# \end{align*}
# In other words, the probability of the union of two events never exceeds the sum of the event probabilities. The equality holds only for mutually exclusive events because $A \cap B = \emptyset$, and therefore, $P(A \cap B) = P(\emptyset)=0$.

# %% [markdown]
# ## Conditional Probabilty

# %% [markdown]
# Given some event $B$ with nonzero probability
# \begin{align*}\tag{1.4-3}
# P(B) \gt 0
# \end{align*}
# we define the _conditional probability_ of an event $A$, given $B$, by
# \begin{align*}\tag{1.4-4}
# P(A|B) = \frac{P(A \cap B)}{P(B)}
# \end{align*}
# The probability $P(A|B)$ simply reflects the fact that the probability of an event $A$ may depend on a second event $B$. If $A$ and $B$ are mutually exclusive, $A \cap B = \emptyset$, and $P(A|B)=0$.
#
# Conditional probability is a defined quantity and cannot be proven. However, as a probability it must satisfy the three axioms given in (1.3-1). $P(A|B)$ obviously satisfies axiom 1 by its definition because $P(A \cap B)$ and $P(B)$ are nonnegative numbers. The second axiom is shown to be satisfied by letting $S=A$:
# \begin{align*}\tag{1.4-5}
# P(S|B) = \frac{P(S \cap B)}{P(B)}=\farc{P(B)}{P(B)}=1
# \end{align*}
# The third axiom may be shown to hold by considering the union of $A$ with an event $C$, where $A$ and $C$ are mutually exclusive. If $P(A \cup C|B) = P(A|B) + P(C|B)$ is true, then axiom 3 holds. Since $A \cap C = \emptyset$ then events $A \cap B$ and $B \cap C$ are mutually exclusive (use a Venn diagram to verify this fact) and
# \begin{align*}\tag{1.4-6}
# P[(A \cup C) \cap B] = P[(A \cap B) \cup (C \cap B)] = P(A \cap B) + P(C \cap B)
# \end{align*}
# Thus, on substitution into (1.4-4)
# \begin{align*}\tag{1.4-7}
# P[(A \cup C)|B] = \frac{P[(A \cup C) \cap B]}{P(B)} = \frac{P(A \cap B)}{P(B)} + \frac{P(C \cap B)}{P(B)}
# \end{align*}
# and axiom 3 holds.

# %% [markdown]
# __EXAMPLE 1.4-1__. In a box there are 100 resistors having resistance and tolerance as shown in Table 1.4-1. Let a resistor be selected from the box and assume each resistor has the same likelihood of being chosen. Define three events: $A$ as "draw a 47-$\Omega$ resistor," $B$ as "draw a resistor with $5\%$ tolerance," and $C$ as "draw a 100-$\Omega$ resistor." From the table, the applicable probabilities are
# \begin{align*}
# P(A) &= P(47 \Omega) = \frac{44}{100} \\
# P(B) &= P(5\%) = \frac{62}{100} \\
# P(C) &= P(100 \Omega) = \frac{32}{100}
# \end{align*}
# The joint probabilities are
# \begin{align*}
# P(A \cap B) &= P(47 \Omega \cap 5\%) = \frac{28}{100} \\
# P(A \cap C) &= P(47 \Omega \cap 100 \Omega) = 0 \\
# P(B \cap C) &= P(5\% \cap 100 \Omega) = \frac{24}{100}
# \end{align*}
# By using (1.4-4) the conditional probabilities become
# \begin{align*}
# P(A|B) &= \frac{P(A \cap B)}{P(B)} = \frac{28}{62} \\
# P(A|C) &= \frac{P(A \cap C)}{P(C)} = 0 \\
# P(B|C) &= \frac{P(B \cap C)}{P(C)} = \frac{24}{32}
# \end{align*}
# $P(A|B) = P(47\Omega|5\%)$ is the probability of drawing a 47-$\Omega$ resistor given that the resistor drawn is $5\%$. $P(A|C) = P(47\Omega|100\Omega)$ is the probability of drawing a 47-$\Omega$ resistor given that the resistor drawn is 100$\Omega$; this is clearly an impossible event so the probability of it is 0. Finally, $P(B|C)=P(5\%|100\Omega)$ is the probability of drawing a resistor of $5\%$ tolerance given that the resistor is 100$\Omega$.
#
# __TABLE 1.4-1__: Numbers of resistors in a box having given resistance and tolerance
# |Resistance ($\Omega$)| $5\%$ | $10\%$ | Total |
# |---|---|---|---|
# |22|10|14|24|
# |47|28|16|44|
# |100|24|8|32|
# |Total|62|38|100|

# %% [markdown]
# ## Total probability
# The probability $P(A)$ of any event $A$ defined on a sample space $S$ can be expressed in terms of conditional probabilities. Suppose we are given $N$ mutually exclusive events $B_n, n = 1, 2, \ldots, N$, whose union equals $S$ as illustrated in Figure 1.4-1. These events satisfy
# \begin{align*}
# B_m \cap B_n = \emptyset \qquad \qquad m \ne n = 1, 2, \ldots, N\tag{1.4-8} \\
# \\
# \bigcup^N_{n=1}B_n = S\tag{1.4-9}
# \end{align*}
# We shall prove that
# \begin{align*}\tag{1.4-10}
# P(A) = \sum^N_{n=1}P(A|B_n)P(B_n)
# \end{align*}
# which is known as the _total probability_ of event $A$.
#
# Since $A \cap S = A$, we may start the proof using (1.4-9) and (1.2-8):
# \begin{align*}\tag{1.4-11}
# A \cap S = A \cap \left(\bigcup^N_{n=1}B_n\right) = \bigcup^N_{n=1}(A \cap B_n)
# \end{align*}
# Now the events $A \cap B_n$ are mutually exclusive as seen from the Venn diagram (Fig. 1.4-1). By applying axiom 3 to these events, we have
# \begin{align*}\tag{1.4-12}
# P(A) = P(A \cap S) = P \left[ \bigcup^N_{n=1}(A \cap B_n) \right] = \sum^N_{n=1}P(A \cap B_n)
# \end{align*}
# where (1.4-11) has been used. Finally, (1.4-4) is substituted into (1.4-12) to obtain (1.4-10).

# %% [markdown]
# ## Bayes' Theorem
# The definition of conditional probability, as given by (1.4-4), applies to any two events. In particular, let $B_n$ be one of the events defined above in the subsection on total probability. Equation (1.4-4) can be written
# \begin{align*}\tag{1.4-14}
# P(B_n|A) = \frac{P(B_n \cap A)}{P(A)}
# \end{align*}
# if $P(A) \ne 0$, or, alternatively,
# \begin{align*}\tag{1.4-14}
# P(A|B_n) = \frac{P(A \cap B_n)}{P(B_n)}
# \end{align*}
# if $P(B_n) \ne 0$. One form of Bayes' theorem is obtained by equating these two expressions:
# \begin{align*}\tag{1.4-15}
# P(B_n|A) = \frac{P(A|B_n)P(B_n)}{P(A)}
# \end{align*}
# Another form derives from a substitution of $P(A)$ as given by (1.4-10),
# \begin{align*}\tag{1.4-16}
# P(B_n|A) = \frac{P(A|B_n)P(B_n)}{P(A|B_1)P(B_1)+\cdots+P(A|B_N)P(B_N)}
# \end{align*}
# for $n = 1, 2, \ldots, N$.

# %% [markdown]
# __EXAMPLE 1.4-2__. An elementary binary communication system consists of a transmitter that sends one of two possible symbols (a 1 or a 0) over a channel to a receiver. The channel occasionally causes errors to occur so that a 1 shows up at the receiver as a 0, and vice versa.
#
# The sample space has two elements (0 or 1). We denote by $B_i, i = 1, 2$, the events "the symbol before the channel is 1," and "the symbol before the channel is 0," respectively. Furthermore, define, $A_i, i = 1, 2$, as the events "the symbol after the channel is 1," and "the symbol after the channel is 0," respectively. The probabilities that the symbols 1 and 0 are selected for transmission are assumed to be
# \begin{align*}
# P(B_1) = 0.6 \qquad \text{and} \qquad P(B_2) = 0.4
# \end{align*}
# Conditional probabilities describe the effect the channel has on the transmitted symbols. The reception probabilities given a 1 was transmitted are assumed to be
# \begin{align*}
# P(A_1|B_1) = 0.9 \\
# P(A_2|B_1) = 0.1
# \end{align*}
# The channel is presumed to to presumed to affect 0s in the same manner so
# \begin{align*}
# P(A_1|B_2) = 0.1 \\
# P(A_2|B_2) = 0.9
# \end{align*}
# In either case, $P(A_1|B_i) + P(A_2|B_i) = 1$ because $A_1$ and $A_2$ are mutually exclusive and are the only "receiver" events (other than the uninteresting events $\emptyset$ and $S$) possible. The channel is often shown diagrammatically as illustrated in Figure 1.4-2. Because of its form it is usually called a _binary symmetric channel_.
#
# From (1.4-10) we obtain the "received" symbol probabilities
# \begin{align*}
# P(A_1) &= P(A_1|B_1)P(B_1) + P(A_1|B_2)P(B_2) \\
#        &= 0.9(0.6) + 0.1(0.4) = 0.58          \\
# P(A_2) &= P(A_2|B_1)P(B_1) + P(A_2|B_2)P(B_2) \\
#        &= 0.1(0.6) + 0.9(0.4) = 0.42
# \end{align*}
# From either (1.4-15) or (1.4-16) we have
# \begin{align*}
# P(B_1|A_1) = \frac{P(A_1|B_1)P(B_1)}{P(A_1)} = \frac{0.9(0.6)}{0.58} = \frac{0.54}{0.58} \approx 0.931 \\
# P(B_2|A_2) = \frac{P(A_2|B_2)P(B_2)}{P(A_2)} = \frac{0.9(0.4)}{0.42} = \frac{0.36}{0.42} \approx 0.857 \\
# P(B_1|A_2) = \frac{P(A_2|B_1)P(B_1)}{P(A_1)} = \frac{0.1(0.6)}{0.42} = \frac{0.06}{0.42} \approx 0.143 \\
# P(B_2|A_1) = \frac{P(A_1|B_2)P(B_2)}{P(A_1)} = \frac{0.1(0.4)}{0.58} = \frac{0.04}{0.58} \approx 0.069
# \end{align*}
# These last two numbers are probabilities of system error while $P(B_1|A_1)$ and $P(B_2|A_2)$ are probabilities of correct system transmission of symbols.

# %% [markdown]
# In Bayes' theorem (1.4-16), the probabilities $P(B_n)$ are usually referred to as _a priori probabilities_, since they apply to the events $B_n$ before the performance of the experiment. Similarly, the probabilities $P(A|B_n)$ are numbers typically known prior to conducting the experiment. Example 1.4-2 described such a case. The conditional probabilities are sometimes called _transition probabilities_ in a comunications context. On the other hand, the probabilities $P(B_n|A)$ are called _a posteriori probabilities_, since they apply after the experiment's performance when some event $A$ is obtained.

# %% [markdown]
# __EXAMPLE 1.4-3__. A student takes a commuter train to get to a school's campus and to class. The probability the student will arrive at class on time is $0.95$ provided the train is on time. If the train is known to be on schedule $70\%$ of the time, what is the probability the student will be on time to class? Here we use Bayes' rule and interpret the relative frequency $70\%$ as the probability of the train's being on time. Let $C$ represent the event the student arrives in class and $T$ represent the train arrives on time. The student will arrive on time if the joint event $C \cap T$ is true. The probability of this event is $P(C \cap T) = P(C|T)P(T) = 0.95(0.70) = 0.665$ from (1.4-13).

# %% [markdown]
# __EXAMPLE 1.4-4__. A box contains 6 green balls, 4 black balls, and 10 yello balls. All balls are equally likely (probable) to be drawn. What is the probability of drawing 2 green balls from the box if the ball on the first draw is not replaced? Let $G$ represent the event "draw a green ball." An application of relative frequency to the first draw suggests that $P(G) = 6/20 = 0.3$. On the second draw we operate with 5 green 4 black, and 10 yellow balls because the first draw _must_ result in a green ball. For the second draw, $P(G|G) = 5/19$ and Bayes' rule gives $P(G \cap G) = P(G|G)P(G) = (5/19)0.3 = 1.5/19 - 0.0789 \approx 8\%$
