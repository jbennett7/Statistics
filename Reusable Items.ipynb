# %% [markdown]
# # Reusable Items

# %% [markdown]
# Table 2.6 from solved problem 2.3

# %%
breaks <- seq(25000, 32000, by=1000)
f <- c(8, 10, 16, 14, 10, 5, 2)
s1 <- c()
for(i in 1:length(f)){
    s2 <- sample(breaks[i]:(breaks[i+1]-1), f[i], replace=TRUE)
    s1 <- sample(c(s1, s2))
    rm(s2)
}
s1 <- s1/100
breaks <- breaks/100
table(cut(s1, breaks=breaks, right=FALSE))
# Out:
# [250,260) [260,270) [270,280) [280,290) [290,300) [300,310) [310,320)
#         8        10        16        14        10         5         2

# %%
jb.norm <- function(x) (1/sqrt(2*pi))*exp(-x^2/2)
x <- seq(-4,4,by=.01)
plot(x, jb.norm(x),type="l")
# Out:
# plot without title
