# %% [markdown]
# # The poisson distribution
# The discrete probability distribution
# \begin{equation}\tag{5}
# p(X) = \frac{\lambda^X e^{-\lambda}}{X!} \ \ \ \ \ \ \ \ X = 0,1,2,\ldots
# \end{equation}
# where $e = 2.71828\ldots$ and $\lambda$ is a given constant, is called the _Poisson distribution_ after Simeon-Denis Poisson, who discovered it in the early part of the nineteenth century. The values of $p(X)$ can be computed by using the table in Appendix VIII (which gives values of $e^{-\lambda}$ for various values of $\lambda$) or by using logarithms.
#
# __EXAMPLE 6.__ The number of admissions per day at an emergency room has a Poisson distribution and the mean is 5. Find the probability of at most $3$ admissions per day and the probability of at least $8$ admissions per day. The probability of at most $3$ is $\text{Pr}\{X \le 3\}=e^{-5}\{5^0/0! + 5^1/1! + 5^2/2! + 5^3/3!\}$. From Appendix VIII, $e^{-5}=0.006738$, and $\text{Pr}\{X \le 3\}=0.006738\{1 + 5 + 12.5 + 20.8333\} = 0.265$.

# %%
ppois(3,lambda=5)
# Out:
# [1] 0.2650259

# %% [markdown]
# Some properites of the Poisson distribution are listed in Table 7.3.
# |Table 7.3|Poisson's Distribution|
# |---|---|
# |Mean|$\mu = \lambda$|
# |Variance|$\sigma^2 = \lambda$|
# |Standard deviation|$\sigma = \sqrt{\lambda}$|
# |Moment coefficient of skewness|$\alpha_3 = 1/\sqrt{\lambda}$|
# |Moment coefficient of kurtosis|$\alpha_4 = 3 + 1/\lambda$|

# %%
?dpois
# Out:
# Poisson                 package:stats                  R Documentation
#
# n
#
# n:
#
#      Density, distribution function, quantile function and random
#      generation for the Poisson distribution with parameter ‘lambda’.
#
# e:
#
#      dpois(x, lambda, log = FALSE)
#      ppois(q, lambda, lower.tail = TRUE, log.p = FALSE)
#      qpois(p, lambda, lower.tail = TRUE, log.p = FALSE)
#      rpois(n, lambda)
#
# s:
#
#        x: vector of (non-negative integer) quantiles.
#
#        q: vector of quantiles.
#
#        p: vector of probabilities.
#
#        n: number of random values to return.
#
#   lambda: vector of (non-negative) means.
#
# log, log.p: logical; if TRUE, probabilities p are given as log(p).
#
# lower.tail: logical; if TRUE (default), probabilities are P[X <= x],
#           otherwise, P[X > x].
#
# s:
#
#      The Poisson distribution has density
#
#                        p(x) = lambda^x exp(-lambda)/x!
#
# ...
