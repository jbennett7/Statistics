# %% [markdown]
# # The multinomial distribution
# If events $E_1,E_2,\ldots,E_K$ can occur with probabilities $p_1,p_2,\ldots,p_K$, repsectively, then the probability that $E_1,E_2,\ldots,E_K$ will occur $X_1,X_2,\ldots,X_K$ times, respectively, is
# \begin{equation}\tag{6}
# \frac{N!}{X_1!X_2!\cdots X_K!}p_1^{X_1}p_2^{X_2}\cdots p_K^{X_K}
# \end{equation}
# where $X_1+X_2+\cdots+X_K=N$. This distribution, which is a generalization of the binomial distribution, is called the _multinomial distribution_ since equation (6) is the general term in the _multinomial expansion_ $(p_1+p_2+\cdots+p_K)^N$.
#
# __EXAMPLE 7.__ If a fair die is tossed $12$ times, the probability of getting $1,2,3,4,5,$ and $6$ points exactly twice each is
# \begin{align}
# \frac{12!}{2!2!2!2!2!2!}\left(\frac{1}{6}\right)^2
#                          \left(\frac{1}{6}\right)^2
#                          \left(\frac{1}{6}\right)^2
#                          \left(\frac{1}{6}\right)^2
#                          \left(\frac{1}{6}\right)^2
#                          \left(\frac{1}{6}\right)^2 =
# \frac{1925}{559,872} = 0.00344
# \end{align}
# The _expected_ numbers of times that $E_1,E_2,\ldots,E_K$ will occur in $N$ trials are $N_{p_1},N_{p_2},\ldots,N_{p_K}$, respectively.

# %%
dmultinom(x=c(2,2,2,2,2,2),prob=c(1/6,1/6,1/6,1/6,1/6,1/6))
# Out:
# [1] 0.003438286

# %%
?dmultinom
# Out:
# Multinom                 package:stats                 R Documentation
#
# n
#
# n:
#
#      Generate multinomially distributed random number vectors and
#      compute multinomial probabilities.
#
# e:
#
#      rmultinom(n, size, prob)
#      dmultinom(x, size = NULL, prob, log = FALSE)
#
# s:
#
#        x: vector of length K of integers in ‘0:size’.
#
#        n: number of random vectors to draw.
#
#     size: integer, say N, specifying the total number of objects that
#           are put into K boxes in the typical multinomial experiment.
#           For ‘dmultinom’, it defaults to ‘sum(x)’.
#
#     prob: numeric non-negative vector of length K, specifying the
#           probability for the K classes; is internally normalized to
#           sum 1. Infinite and missing values are not allowed.
#
#      log: logical; if TRUE, log probabilities are computed.
#
# s:
#
#      If ‘x’ is a K-component vector, ‘dmultinom(x, prob)’ is the
#      probability
#
# ...
