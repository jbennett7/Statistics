# %% [markdown]
# # Class boundaries
# If heights are recorded to the nearest inch, the class interval `60-62` theoretically includes all measurements from $59.5000$ to $62.5000$ in. These numbers, indicated briefly by the exact numbers $59.5$ and $62.5$, are called _class boundaries_, or _true class limits_; the smaller number $(59.5)$ is the _lower class boundary_, and the larger number $(62.5)$ is the _upper class boundary_.
#
# In practice, the class boundaries are obtained by adding the upper limit of one class interval to the lower limit of the next-higher class interval and dividing by $2$.
#
# Sometimes, class boundaries are used to symbolize classes. For example, the various classes in the first column of Table 2.1 could be indicated by $59.4$&ndash;$62.5$, $62.5$&ndash;$65.5$, etc. To avoid ambiguity in using such notation, class boundaries should not coincide with actual observations. Thus if an observation were $62.5$, it would not be possible to decide whether it belonged to the class interval $59.5$&ndash;$62.5$ or $62.5$&ndash;$65.5$.

# %% [markdown]
# ---

# %%
load('../../Saves/Table_2.1.Rdata')
Table.2.1
# Out:
#   Height Freq
# 1 60-62   5
# 2 63-65  18
# 3 66-68  42
# 4 69-71  27
# 5 72-74   8

# %%
Table.2.1$Height
# Out:
# [1] 60-62 63-65 66-68 69-71 72-74
# Levels: 60-62 63-65 66-68 69-71 72-74

# %%
cat("Lower class boundaries:", lower.boundaries <- seq(59.5, 71.5, by=3), "\n")
cat("Upper class boundaries:", upper.boundaries <- seq(62.5, 74.5, by=3), "\n")
# Out:
# Lower class boundaries: 59.5 62.5 65.5 68.5 71.5
# Upper class boundaries: 62.5 65.5 68.5 71.5 74.5
