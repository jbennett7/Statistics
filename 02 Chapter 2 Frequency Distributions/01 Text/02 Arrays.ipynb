# %% [markdown]
# # Arrays
# An _array_ is an arrangement of raw numerical data in ascending or descending order of magnitude. The difference between the largest and smallest numbers is called the _range_ of data. For example, if the largest height of $100$ male students is $74$ inches (in) and the smallest height is $60$in, the range is $74-60=14$in.

# %% [markdown]
# ---

# %% [markdown]
# ## R programming arrays

# %% [markdown]
# This is a vector data set.

# %%
load("../../Saves/Problem_2.2.Rdata")
cat(P2.2.data)
# Out:
# 68 84 75 82 68 90 62 88 76 93 73 79 88 73 60 93 71 59 85 75 61 65 75 87 74 62 95 78 63 72 66 78 82 75 94 77 69 74 68 60 96 78 89 61 75 95 60 79 83 71 79 62 67 97 78 85 76 65 71 75 65 80 73 57 88 78 62 76 53 74 86 67 73 81 72 63 76 75 85 77

# %% [markdown]
# To convert an R vector to the definition of an array, sort the vector either ascending or descending. The range in R is a two value vector that contains the smallest and largest value. To get the range defined above use `diff`:

# %%
cat("Sorted array:\n", sort(P2.2.data), "\n\n")
cat("Reverse sorted array:\n", rev(sort(P2.2.data)), "\n\n")
cat("Range:", diff(range(P2.2.data)), "\nSmallest value:",
    range(P2.2.data)[1], "\nLargest value:", range(P2.2.data)[2], "\n")
# Out:
# Sorted array:
#  53 57 59 60 60 60 61 61 62 62 62 62 63 63 65 65 65 66 67 67 68 68 68 69 71 71 71 72 72 73 73 73 73 74 74 74 75 75 75 75 75 75 75 76 76 76 76 77 77 78 78 78 78 78 79 79 79 80 81 82 82 83 84 85 85 85 86 87 88 88 88 89 90 93 93 94 95 95 96 97
#
# Reverse sorted array:
#  97 96 95 95 94 93 93 90 89 88 88 88 87 86 85 85 85 84 83 82 82 81 80 79 79 79 78 78 78 78 78 77 77 76 76 76 76 75 75 75 75 75 75 75 74 74 74 73 73 73 73 72 72 71 71 71 69 68 68 68 67 67 66 65 65 65 63 63 62 62 62 62 61 61 60 60 60 59 57 53
#
# Range: 44
# Smallest value: 53
# Largest value: 97

# %% [markdown]
# Another way of generating Table [2.5](../02%20Solved%20Problems/01%20Arrays.ipynb#Table-2-5) is using the `stem` function. The `stem` function generates a stem and leaf plot.

# %%
stem(P2.2.data)
# Out:
#   The decimal point is 1 digit(s) to the right of the |
#
#   5 | 3
#   5 | 79
#   6 | 00011222233
#   6 | 5556778889
#   7 | 111223333444
#   7 | 555555566667788888999
#   8 | 012234
#   8 | 555678889
#   9 | 0334
#   9 | 5567

# %%
?stem
# Out:
# stem                 package:graphics                  R Documentation
#
# s
#
# n:
#
#      ‘stem’ produces a stem-and-leaf plot of the values in ‘x’.  The
#      parameter ‘scale’ can be used to expand the scale of the plot.  A
#      value of ‘scale = 2’ will cause the plot to be roughly twice as
#      long as the default.
#
# e:
#
#      stem(x, scale = 1, width = 80, atom = 1e-08)
#
# s:
#
#        x: a numeric vector.
#
#    scale: This controls the plot length.
#
#    width: The desired width of plot.
#
#     atom: a tolerance.
#
# s:
#
#      Infinite and missing values in ‘x’ are discarded.
#
# s:
#
#      Becker, R. A., Chambers, J. M. and Wilks, A. R. (1988) _The New S
#      Language_.  Wadsworth & Brooks/Cole.
#
# s:
#
#      stem(islands)
#      stem(log10(islands))
