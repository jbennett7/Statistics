# %% [markdown]
# # The size, or width, of a class interval
# The size, or width, of a class interval is the difference between the lower and upper class boundaries and is also referred to as the _class width_, _class size_, or _class length_. If all class intervals of a frequency distribution have equal widths, this common width is denoted by $c$. In such case $c$ is equal to the difference between two successive lower class limits or two successive upper class limtits. For the data of [Table 2.1](03%20frequency%20distributions.ipynb#Table-2-1), for example, the class interval is $c = 62.5 - 59.5 = 65.5 - 62.5 = 3$.

# %% [markdown]
# ---

# %%
load('../../Saves/Table_2.1.Rdata')
Table.2.1
# Out:
#   Height Freq
# 1 60-62   5
# 2 63-65  18
# 3 66-68  42
# 4 69-71  27
# 5 72-74   8

# %% [markdown]
# If the class intervals of a frequency distribution have equal widths, then you can easily generate the class boundaries and class limits using this value `c`:

# %%
c <- 3
cat("Class interval:", c, "\n")
cat("Class limits:\n\t", "Lower limits:", 
    seq(60, 72, by=c), "\n\t", "Upper limits:", seq(62, 74, by=c), "\n")
cat("Class boundaries:\n\t", "Lower boundaries:", 
    seq(59.5, 71.5, by=c), "\n\t", "Upper boundaries:", seq(62.5, 72.5, by=c), "\n")
# Out:
# Class interval: 3
# Class limits:
# 	 Lower limits: 60 63 66 69 72
# 	 Upper limits: 62 65 68 71 74
# Class boundaries:
# 	 Lower boundaries: 59.5 62.5 65.5 68.5 71.5
# 	 Upper boundaries: 62.5 65.5 68.5 71.5
