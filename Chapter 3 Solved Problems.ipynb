# %% [markdown]
# # Chapter 3 Solved Problems

# %% [markdown]
# ## Solved Problems

# %% [markdown]
# ### Summation notation

# %% [markdown]
# 5. The following table is the amount of taxes collected in the United States. Find what the sum is.

# %%
item <- c(
    "Sales and receipts",
    "Income",
    "Licenses",
    "Others",
    "Property"
)
amount.collected <- c(1051.42, 875.23, 144.33, 80.49, 38.36)
df <- data.frame(item,amount.collected)
df
sum(df$amount.collected)
# Out:
#   item               amount.collected
# 1 Sales and receipts 1051.42
# 2 Income              875.23
# 3 Licenses            144.33
# 4 Others               80.49
# 5 Property             38.36
# [1] 2189.83

# %% [markdown]
# ### The arithmetic mean

# %%
# 3.6 The grades of a student on six examinations are shown below what is the arithmetic mean.
p6.X <- grades <- c(84, 91, 72, 68, 87, 78)
p6.N <- length(p6.X)
sum(p6.X)/p6.N
# OR
p6.X.bar <- mean(p6.X)
p6.X.bar
# Out:
# [1] 80
# [1] 80

# %%
# 3.7 Ten measurements of the diameter of a cylinder were recorded by a scientist. What is the arithmetic mean
p7.X <- measurements <- c(3.88, 4.09, 3.92, 3.97, 4.02, 3.95, 4.03, 3.92, 3.98, 4.06)
p7.X.bar <- round(mean(p7.X),2)
p7.X.bar
# Out:
# [1] 3.98

# %%
# 3.9 Arithmetic mean
X <- numbers <- c(5, 3, 6, 5, 4, 5, 2, 8, 6, 5, 4, 8, 3, 4, 5, 4, 8, 2, 5, 4)
X.bar <- mean(numbers)

# %%
# 3.10 Out of 100 numbers, 20 were 4's, 40 were 5's, 30 were 6's, and the remainder were 7's.
# Find the arithmetic mean
N <- 100
sevens <- N - 20 - 40 - 30
X <- set <- c(4, 5, 6, 7)
f <- c(20, 40, 30, sevens)
X.bar <- sum(f*X)/N
X.bar
# Out:
# [1] 5.3

# %%
# 3.11 A student's final grades in mathematics, physics, english and hygiene are, respectively, 82, 86, 90, and 70.
# If the respective credits received for these courses are 3, 5, 3, and 1, determine an appropriate average grade.

X <- grades <- c(82, 86, 90, 70)
N <- length(X)
w <- weights <- c(3, 5, 3, 1)
X.bar = sum(w*X)/sum(w)
round(X.bar,0)
# Out:
# [1] 85

# %%
# 3.12 In a company having 80 employees, 60 earn $10.00 per hour and 20 earn $13.00 per hour.
#
# (a) Determine the mean earnings per hour.
# (b) Would the answer in part (a) be the same if the 60 employees earn a mean hourly wage of
#     $10.00 per hour? Prove your answer.
# (c) Do you believe the mean hourly wage to be typical?

X <- earnings <- c(10.00, 13)
f <- weights <- c(60, 20)
N <- sum(f)
round(sum(X*f)/N,2)
# Out:
# [1] 10.75

# %%
# 3.13 Four groups of students, consisting of 15, 20, 10, and 18 individuals,
# reported mean weights of 162, 148, 153, and 140 pounds (lb), respectively. 
# Find the mean weight of all the students.
X <- student.weights <- c(162, 148, 153, 140)
f <- num.students <- c(15, 20, 10, 18)
N <- sum(f)
round(sum(f*X)/sum(N))
# Out:
# [1] 150

# %%
# 3.15 Use the following frequency distribution of heights to find the mean height of the 100 male
# students.

height.classes <- c(
    "60-62",
    "63-65",
    "66-68",
    "69-71",
    "72-74"
)
f <- number.of.students <- c(5, 18, 42, 27, 8)
N <- sum(f)
df <- data.frame(height.classes, number.of.students)
df
X <- class.marks <- c(61, 64, 67, 70, 73)
round(sum(f*X)/N,2)
# Out:
#   height.classes number.of.students
# 1 60-62           5
# 2 63-65          18
# 3 66-68          42
# 4 69-71          27
# 5 72-74           8
# [1] 67.45

# %% [markdown]
# ### Properties of the arithmetic mean

# %% [markdown]
# #### 3.16
# Prove that the sum of the deviations of $X_1, X_2,...,X_N$ from their mean $\bar{X}$ is equal to zero.

# %% [markdown]
# #### Solution
# Let $d_1 = X_1 - \bar{X}, d_2 = X_2 - \bar{X},...,d_N = X_N - \bar{X}$ be the deviations of
# $X_1, X_2,...,X_N$ from their mean $\bar{X}$. Then
#
# $$
# \begin{align*}
# \text{Sum of deviations}
# = \sum{d_j}
# = \sum{(X_j - \bar{X})}
# = \sum{X_j} - N\bar{X}
# = \sum{X_j} - N\left(\frac{\sum{X_j}}{N}\right)
# = \sum{X_j} - \sum{X_j} = 0
# \end{align*}
# $$
#
# where we have used $\sum$ in place of $\sum_{j=1}^N$. We could, if desired, have omitted the subscript $j$ in $X_j$, provided that it is _understood_.

# %% [markdown]
# #### 3.17
# If $Z_1 = X_1 + Y_1, Z_2 = X_2 + Y_2,...,Z_N = X_N + Y_N$, prove that $\bar{Z} = \bar{X} + \bar{Y}$.

# %% [markdown]
# #### Solution
# By definition,
# $$
# \begin{align*}
# \bar{X} = \frac{\sum{X}}{N}
# \ \ \ \ \ \ \ \ \ \ \
# \bar{Y} = \frac{\sum{Y}}{N}
# \ \ \ \ \ \ \ \ \ \ \
# \bar{Z} = \frac{\sum{Z}}{N}
# \end{align*}
# $$
# Thus
# $$
# \begin{align*}
# \bar{Z}
# = \frac{\sum{Z}}{N}
# = \frac{\sum{(X+Y)}}{N}
# = \frac{\sum{X}+\sum{Y}}{N}
# = \frac{\sum{X}}{N}+\frac{\sum{Y}}{N}
# = \bar{X} + \bar{Y}
# \end{align*}
# $$
#
# where the subscripts $j$ on $X$, $Y$, and $Z$ have been omitted and where $\sum$ means $\sum_{j=1}^N$.

# %% [markdown]
# #### 3.18
# (a) If $N$ numbers $X_1, X_2,...,X_N$ have deviations from any number $A$ given by $d_1 = X_1 - A$,
# $d_2 = X_2 - A,...,d_N = X_N - A$, respectively, prove that:
#
# $$
# \begin{align*}
# \bar{X} = A + \frac{\sum_{j=1}^N{d_j}}{N} = A + \frac{\sum{d}}{N}
# \end{align*}
# $$
#
#
# (b) In case $X_1, X_2,...,X_K$ have respective frequencies $f_1, f_2,...,f_K$ and
# $d_1 = X_1 - A,...,d_K = X_K - A$, show that the result in part (a) is replaced with
#
# $$
# \begin{align*}
# \bar{X} = A + \frac{\sum_{j=1}^K{f_jd_j}}{\sum_{j=1}^K{f_j}} = A + \frac{\sum{fd}}{N}\text{   where   }
# \sum_{j=1}^K{f_j} = \sum{f} = N
# \end{align*}
# $$

# %% [markdown]
# #### Solution (a) First method
# $$
# \begin{align*}
# \bar{X} = A + \frac{\sum{X_j}}{N} = \frac{\sum(A+d_j)}{N} = \frac{\sum{A}+\sum{d_j}}{N} = \frac{NA+\sum{d_j}}{N}=
# A+\frac{\sum{d_j}}{N}
# \end{align*}
# $$
#
# where we have used $\sum$ in place of $\sum_{j=1}^N$ for brevity.

# %% [markdown]
# #### Solution (a) Second method
# We have $d=X-A$, or $X=A+d$, omitting the subscripts on $d$ and $X$. Thus, by Problem 3.17,
#
# $$
# \begin{align*}
# \bar{X} = \bar{A}+\bar{d} = A + \frac{\sum{d}}{N}
# \end{align*}
# $$
#
# since the mean of a number of constants all equal to $A$ is $A$.

# %% [markdown]
# #### Solution (b)
# $$
# \begin{align*}
# \bar{X}
# = \frac{\sum_{j=1}^K{f_jX_j}}{\sum_{j=1}^K{f_j}}
# = \frac{\sum{f_jX_j}}{N}
# = \frac{\sum{f_j(A+d_j)}}{N}
# = \frac{\sum{Af_j} + \sum{f_jd_j}}{N}
# = \frac{A\sum{f_j} + \sum{f_jd_j}}{N}
# = \frac{AN + \sum{f_jd_j}}{N}
# = A + \frac{\sum{f_jd_j}}{N}
# = A + \frac{\sum{fd}}{N}
# \end{align*}
# $$
#
# Note that _formally_ the result is obtained from part (a) by replacing $d_j$ with $f_jd_j$ and summing from
# $j = 1$ to $K$ instead of from $j = 1$ to $N$. The result is equialent to $\bar{X} = A + \bar{d}$, where
# $\bar{d} = \left(\sum{fd}\right)/N$

# %% [markdown]
# ### The arithmetic mean computed from grouped data

# %%
# 3.19 Use the method of Problem 3.18(a) to find the arithmetic mean of the numbers 
# 5, 8, 11, 9, 12, 6, 14, and 10, choosing as the "guessed mean" A the values (a) 9 and (b) 20.
set <- c(5, 8, 11, 9, 12, 6, 14, 10)
N <- length(set)
guess.a <- 9
guess.b <- 20
sum.d.a <- sum(set - guess.a)
sum.d.b <- sum(set - guess.b)
guess.a + (sum.d.a/N)
guess.b + (sum.d.b/N)
# Out:
# [1] 9.375
# [1] 9.375

# %%
# 3.20 Use the method of Problem 3.18(b) to find the arithmetic mean of the heights of the 100 male students
# at XYZ University.
height.classes <- c(
    "60-62",
    "63-65",
    "66-68",
    "69-71",
    "72-74"
)
f <- number.of.students <- c(5, 18, 42, 27, 8)
N <- sum(f)
df <- data.frame(height.classes, number.of.students)
df
X <- avg.class.height <- c(61, 64, 67, 70, 73)
A <- guess <- 67
d <- X - A
x.bar <- avg <- A + sum(f*d)/N
x.bar
# Out:
#   height.classes number.of.students
# 1 60-62           5
# 2 63-65          18
# 3 66-68          42
# 4 69-71          27
# 5 72-74           8
# [1] 67.45

# %% [markdown]
# #### 3.21
# Let $d_j - X_j - A$ denote the deviations of any class mark $X_j$ in a frequency distribution from a given class mark $A$. Show that if all class intervals have equal _size_ $c$, then (a) the deviations are all multiples 0f $c$ (i.e., $d_j = cu_j$, where $u_j = 0$, $\pm1$, $\pm2$,...) and (b) the arithmetic mean can be computed from the formula
#
# $$
# \begin{align*}
# \bar{X} = A + \left(\frac{\sum{fu}}{N}\right)c
# \end{align*}
# $$

# %% [markdown]
# #### Solution
# (a) The result is illustrated in the following table, where it is observed that the deviations in column 2 are all multiples ofof the class-interval size $c = 3$ in.
#
# To see that the result is true in general, note that if $X_1$, $X_2$, $X_3$,... are successive class marks, their common difference will for this case be equal to $c$, so that $X_2 = X_1 + c$, $X_3 = X_1 + 2c$, and in general $X_j = X_1 + (j-1)c$. Then any two class marks $X_p$ and $X_q$, for example, will differ by
#
# $$
# \begin{align*}
# X_p - X_q = [X_1 + (p - 1)c]-[X_1 + (q - 1)c] = (p - q)c
# \end{align*}
# $$
#
# which is a multiple of $c$.
#
# (b) By part (a), the deviations of all the calss marks from any given one are multiples of $c$ (i.e., $d_j=cu_j$). Then, using Problem 3.18(b), we have
#
# $$
# \begin{align*}
# \bar{X}
# = A + \frac{\sum{f_jd_j}}{N}
# = A + \frac{\sum{f_j(cu_j)}}{N}
# = A + c\frac{\sum{f_ju_j}}{N}
# = A + \left(\frac{\sum{fu}}{N}\right)c
# \end{align*}
# $$
#
# Note that this is equivalent to the result $\bar{X} = A + c\bar{u}$, which can be obtained from $\bar{X} = A + \bar{d}$ by placing $d = cu$ and observing that $\bar{d} = c\bar{u}$ (see Problem 3.18)

# %%
X <- c(61, 64, 67, 70, 73)
A <- X[3]
d <- c(-6, -3, 0, 3, 6)
f <- c(5, 18, 42, 27, 8)
fd <- f*d
df <- data.frame(X,d,f,fd)
df
N <- sum(df$f)
X.bar <- A + sum(df$fd)/N
X.bar
# Out:
#   X  d  f  fd
# 1 61 -6  5 -30
# 2 64 -3 18 -54
# 3 67  0 42   0
# 4 70  3 27  81
# 5 73  6  8  48
# [1] 67.45

# %% [markdown]
# #### 3.22
# Use the result of Problem 3.21(b) to find the mean height of the $100$ maile students at XYZ University.

# %% [markdown]
# #### Solution
# The work may be arranged as in the following table. The method is called the _coding method_ and should be employed whenever possible.

# %%
X <- c(61, 64, 67, 70, 73)
A <- X[3]
u <- c(-2, -1, 0, 1, 2)
f <- c(5, 18, 42, 27, 8)
fu <- c(-10, -18, 0, 27, 16)
df <- data.frame(X,u,f,fu)
df
N <- sum(f)
sum.fu <- sum(fu)
sum.fu
c <- unique(diff(X))
X.bar <- A + (sum.fu/N)*c
X.bar
# Out:
#   X  u  f  fu
# 1 61 -2  5 -10
# 2 64 -1 18 -18
# 3 67  0 42   0
# 4 70  1 27  27
# 5 73  2  8  16
# [1] 15
# [1] 67.45

# %% [markdown]
# #### 3.23
# Compute the mean weekly wage of the 65 employees at the P&R Company from the frequency distribution in Table 2.6, using (a) the long method and (b) the coding method.

# %%
wage.classes <- c(
    "$250.00-$259.99",
    "$260.00-$269.99",
    "$270.00-$279.99",
    "$280.00-$289.99",
    "$290.00-$299.99",
    "$300.00-$309.99",
    "$310.00-$319.99"
)
number.of.employees <- c(8, 10, 16, 14, 10, 5, 2)
df1 <- data.frame(wage.classes, number.of.employees)
df1

# (a)
X <- c(255, 265, 275, 285, 295, 305, 315)
f <- number.of.employees
N <- sum(f)
fX <- f*X
df2 <- data.frame(X,f,fX)
sum.fX <- sum(fX)
X.bar <- sum.fX/N
round(X.bar,2)

# (b)
A <- X[3]
c <- unique(diff(X))
u <- c(-2, -1, 0, 1, 2, 3, 4)
fu <- f*u
sum.fu <- sum(fu)
X.bar <- A + sum.fu/N*c
round(X.bar,2)
# Out:
#   wage.classes    number.of.employees
# 1 $250.00-$259.99  8
# 2 $260.00-$269.99 10
# 3 $270.00-$279.99 16
# 4 $280.00-$289.99 14
# 5 $290.00-$299.99 10
# 6 $300.00-$309.99  5
# 7 $310.00-$319.99  2
# [1] 279.77
# [1] 279.77

# %% [markdown]
# #### 3.24
# Using the following table, find the mean wage of the 70 employees at the P&R company.

# %%
wage.classes <- c(
    "$250.00-$259.99",
    "$260.00-$269.99",
    "$270.00-$279.99",
    "$280.00-$289.99",
    "$290.00-$299.99",
    "$300.00-$319.99",
    "$320.00-$379.99"
)

frequency <- c(8, 10, 16, 15, 10, 8, 3)
df <- data.frame(wage.classes, frequency)
df
# Out:
#   wage.classes    frequency
# 1 $250.00-$259.99  8
# 2 $260.00-$269.99 10
# 3 $270.00-$279.99 16
# 4 $280.00-$289.99 15
# 5 $290.00-$299.99 10
# 6 $300.00-$319.99  8
# 7 $320.00-$379.99  3

# %%
# We have to use the long method because the classes are not the same size.
X <- wage.marks <- c( 255, 265, 275, 285, 295, 310, 350)
f <- frequency
N <- sum(f)
fX <- f*X
sum.fX <- sum(fX)
X.bar <- sum.fX/N
round(X.bar,2)
# Out:
# [1] 283.5

# %% [markdown]
# ### The median

# %% [markdown]
# #### 3.26
# The number of ATM transactions per day were recorded at 15 locations in a large city. The data were: $35$, $49$, $225$, $50$, $30$, $65$, $40$, $55$, $52$, $76$, $48$, $325$, $47$, $32$, and $60$. Find (a) the median number of transactions and (b) the mean number of transactions.

# %%
data <- c(35, 49, 225, 50, 30, 65, 40, 55, 52, 76, 48, 325)
median(data)

# OR

sd <- sort(data)
m <- length(sd)
med <- NA
if(m%%2 != 0){
    i <- (m-1)/2+1
    med <- sd[i]
} else {
    i <- m/2
    med <- (sd[i]+sd[i+1])/2
}
med
# Out:
# [1] 51
# [1] 51

# %% [markdown]
# #### 3.27
# If (a) 85 and (b) 150 numbers are arranged in an array, how would you find the median of the numbers.
#
# #### Solution
# (a) 85 is odd so if the array was ordered, then the 43rd number would be the median.
# (b) 150 is even so if the array was ordered, then the average of the 75th and 76th number would be the median.

# %% [markdown]
# #### 3.28
# For the data below, find the median weight of the 40 male college students at State University by using (a) the frequency distribution table. (b) The original data.

# %%
weighted.median <- function(X, f){
    f.sum <- sum(f)
    N <- length(f)
    c <- diff(X)[1]
    sf <- 0
    nf <- 0
    for(i in 1:length(N)){
        if(sf + f[i] > f.sum/2){
            nf <- i
            break
        }
        sf <- sf + f[i]
    }
    missing <- f.sum/2 - sf
    nf <- f[nf]
    lower <- X[i] - c/2
    upper <- X[i] + c/2
    return(round(lower + (missing/nf)*(upper-lower),1))
}

# %%
data <- weights <- c( 138, 164, 150, 132, 144, 125, 149, 157,
                      146, 158, 140, 147, 136, 148, 152, 144,
                      168, 126, 138, 176, 163, 119, 154, 165,
                      146, 173, 142, 147, 135, 153, 140, 135,
                      161, 145, 135, 142, 150, 156, 145, 128)
breaks <- c(118, 127, 136, 145, 154, 163, 172, 181)
class.size <- 8
h <- hist(data, breaks=breaks, right=FALSE)
df <- data.frame(head(breaks,-1),h$counts)
colnames(df) <- c('break', 'frequency')
df

# (a)
total.frequency <- sum(df$frequency)
half.frequency <- total.frequency/2

summing.frequency <- 0
next.frequency.index <- 0
for(i in 1:length(h$count)){
    if(summing.frequency + h$count[i] > half.frequency){
        next.frequency.index <- i
        break
    }
    summing.frequency <- summing.frequency + h$count[i]
}
missing <- half.frequency - summing.frequency
next.frequency <- h$count[i]
lower <- h$breaks[i] - .5
upper <- h$breaks[i+1] - .5
round(lower + (missing/next.frequency)*(upper-lower),1)
weighted.mean(h$mids, h$counts)

# (b)
sort(data)[20]
sort(data)[20]

round(median(data),1)
# Out:
#   break frequency
# 1 118    3
# 2 127    5
# 3 136    9
# 4 145   12
# 5 154    5
# 6 163    4
# 7 172    2
# [1] 146.8
# [1] 147.475
# [1] 146
# [1] 146
# [1] 146
# Plot with title “Histogram of data”

# %% [markdown]
# #### 3.30
# Find the median wage of the 65 employees at the P&R Company.

# %%
X <- wage.classes <- c(
    "$250.00-$259.99",
    "$260.00-$269.99",
    "$270.00-$279.99",
    "$280.00-$289.99",
    "$290.00-$299.99",
    "$300.00-$309.99",
    "$310.00-$319.99"
)
f <- number.of.employees <- c(8, 10, 16, 14, 10, 5, 2)
df <- data.frame(wage.classes, f)
df
N <- sum(df$f)
half.N <- N/2
breaks <- c( 250.00, 260.00, 270.00, 280.00, 290.00, 300.00, 310.00, 320.00)
nf <- 0
ind <- 0
for(i in 1:length(df$f)){
    if(nf + df$f[i] > half.N){
        ind <- i
        break
    }
    nf <- nf + df$f[i]
}
lower <- breaks[i]-.005
missing <- half.N - nf
round(lower + ((missing)/f[i])*10.00, 2)
# Out:
#   wage.classes    f
# 1 $250.00-$259.99  8
# 2 $260.00-$269.99 10
# 3 $270.00-$279.99 16
# 4 $280.00-$289.99 14
# 5 $290.00-$299.99 10
# 6 $300.00-$309.99  5
# 7 $310.00-$319.99  2
# [1] 279.06

# %% [markdown]
# ### The mode

# %% [markdown]
# #### 3.31
# Find the mean, median, and mode for the sets (a) $3$, $5$, $2$, $6$, $5$, $9$, $5$, $2$, $8$, $6$ and
# (b) $51.6$, $48.7$, $50.3$, $49.5$, $48.9$.

# %%
set.a <- c(3, 5, 2, 6, 5, 9, 5, 2, 8, 6)
set.b <- c(51.6, 48.7, 50.3, 49.5, 48.9)

mean.a.long <- sum(set.a)/length(set.a)
mean.a.quick <- mean(set.a)

median.a.long <- 0
sorted.set.a <- sort(set.a)
if(length(sorted.set.a)%%2 != 0){
    i <- length(sorted.set.a)/2
    median.a.long <- sorted.set.a[i]
} else {
    i <- (length(sorted.set.a)-1)/2
    median.a.long <- (sorted.set.a[i]+sorted.set.a[i+1])/2
}
median.a.quick <- median(set.a)

getmode <- function(v) {
    uniqv <- unique(v)
    uniqv[which.max(tabulate(match(v, uniqv)))]
}
mode.a <- getmode(set.a)
c(mean.a.quick, median.a.quick, mode.a)

mean.b <- mean(set.b)
median.b <- median(set.b)
# This is wrong
mode.b <- getmode(set.b)
c(mean.b, median.b, mode.b)
# Out:
# [1] 5.1 5.0 5.0
# [1] 49.8 49.5 51.6

# %% [markdown]
# ### The empirical relation between the mean, median, and mode

# %% [markdown]
# #### 3.34
# (a) Use the empirical formula mean &mdash; mode = 3(mean &mdash; median) to find the modal wage of the $65$ employees at the P&R Company.

# %%
X <- wage.marks <- c( 255, 265, 275, 285, 295, 305, 315)
f <- number.of.employees <- c(8, 10, 16, 14, 10, 5, 2)
df <- data.frame(wage.marks, f)
N <- sum(f)
fX <- f*X
sum.fX <- sum(fX)
X.bar <- sum.fX/N
mean.df <- round(X.bar,2)

nf <- 0
ind <- 0
for(i in 1:length(df$f)){
    if(nf + df$f[i] > half.N){
        ind <- i
        break
    }
    nf <- nf + df$f[i]
}
lower <- breaks[i]-.005
missing <- half.N - nf
median.df <- round(lower + ((missing)/f[i])*10.00, 2)

c(mean.df, median.df)
mean.df - 3*(mean.df - median.df)
# Out:
# [1] 279.77 279.06
# [1] 277.64

# %% [markdown]
# ### The geometric mean

# %% [markdown]
# #### 3.35
# Find (a) the geometric mean and (b) the arithmetic mean of the numbers $3$, $5$, $6$, $6$, $7$, $10$, and $12$. Assume that the numbers are exact.

# %%
numbers <- c(3,5,6,6,7,10,12)

# Method one
round(prod(numbers)^(1/(length(numbers))),2)

# Method two
round(exp(mean(log(numbers))),2)
# Out:
# [1] 6.43
# [1] 6.43

# %% [markdown]
# #### 3.36
# The numbers $X_1$, $X_2$,...,$X_K$ occur with frequencies $f_1$, $f_2$,...,$f_K$, where $f_1 + f_2 + ... + f_K = N$ is the total frequency. \
# \
# (a) Find the geometric mean $G$ of the numbers. \
# (b) Derive an expression for $\log{G}$. \
# (c) How can the results be used to find the geometric mean for data grouped into a frequency distribution?

# %% [markdown]
# #### Solution
# (a)
# $$
# \begin{align*}
# G = \sqrt[N]{\underbrace{X_2X_2...X_2}_{f_2 \text{times}}\ \underbrace{X_2X_2...X_2}_{f_2 \text{times}}\ldots\ \underbrace{X_KX_K...X_K}_{f_K \text{times}}} = \sqrt[N]{X_1^{f_1}X_2^{f_2}\ldots X_K^{f_K}}
# \end{align*}
# $$
# \
# where $N = \sum{f}$. This is sometimes called the _weighted geometric mean_.

# %% [markdown]
# (b)
# $$
# \begin{align*}
# \log{G}
# = \frac{1}{N}\log{\left(X_1^{f_1}X_2^{f_2}\ldots X_K^{f_K}\right)}
# = \frac{1}{N}\left(f_1\log{X_1} + f_2\log{X_2} + \ldots + f_K\log{X_K}\right)
# = \frac{1}{N}\sum_{j=1}^Kf_j\log{X_j} = \frac{\sum{f}\log{X}}{N}
# \end{align*}
# $$
# \
# where we assume that all the numbers are positive; otherwise, the logarithms are not defined.\
# Note that the logarithm of the geometric mean of a set of positive numbers is the arithmetic mean of the logarithms of the numbers.

# %% [markdown]
# (c)\
# The result can be used to find the geometric mean for grouped data by taking $X_1$, $X_2$,$\ldots$,$X_K$ as class marks and $f_1$, $f_2$,$\ldots$, $f_K$ as the corresponding class frequencies.

# %% [markdown]
# #### 3.37
# During one year the ratio of milk prices per quart to bread prices per loaf was $3.00$, whereas during the next year the ratio was $2.00$.
#
# (a) Find the arithmetic mean of these ratios for the 2-year period.\
# (b) Find the arithmetic mean of the ratios of bread prices to milk prices fo rhte 2-year period.\
# (c) Discuss the advisability of using the arithmetic mean for averaging ratios.\
# (d) Discuss the suitability of the geometric mean for averaging ratios.

# %%
# a
a <- .5*(3.00 + 2.00)
a
# b
b <- round(.5*(1/3.00 + 1/2.00),3)
b
# Out:
# [1] 2.5
# [1] 0.417

# %% [markdown]
# #### c
# We would expect the mean ratio of milk to bread prices to be the reciprocal of the mean ratio of bread to milk prices if the mean is an appropriate average. However, $\frac{1}{0.417} = 2.40 \neq 2.50$. This shows that the arithmetic mean is a poor average to use for ratios.

# %% [markdown]
# #### d
# Geometric mean of ratios of milk to bread $= \sqrt{(3.00)(2.00)} = \sqrt{6.00}$ \
# Geomteric mean of ratios of bread to milk prices $= \sqrt{(0.333)(0.500)} = \sqrt{(0.0167)} = \frac{1}{\sqrt{6.00}}$ \
# Since these averages are reciprocals, our conclusion is that the geometric mean is more suitable than the arithmetic mean for averaging ratios for this type of problem.

# %% [markdown]
# #### 3.38
# The bacterial count in a certain culture increased from $1000$ to $4000$ in $3$ days.What is the average percentage increase per day?

# %% [markdown]
# #### Solution
# Since an increase from $1000$ to $4000$ is a $300\%$ increase, one might be led to conclude that the average percentage increase per day would be $\frac{300\%}{3} = 100\%$. This, however, would imply that during the first day the cout went from $1000$ to $2000$, during the second day from $2000$ to $4000$, and during the third day from $4000$ to $8000$, which is contrary to the facts.
#
# To determine this average percentage increase, let us denote it by $r$. Then
#
# Total bacterial count after $1$ day $= 1000 + 1000r = 1000(1 + r)$
#
# Total bacterial count after $2$ days $= 1000(1 + r) + 1000(1 + r)r = 1000(1 + r)^2$
#
# Total bacterial count after $3$ days $= 1000(1 + r)^2 + 1000(1 + r)^2r = 1000(1 + r)^3$
#
# This last expression must equal $4000$. Thus $1000(1 + r)^3 = 4000, (1 + r)^2 = 4, 1 + r = \sqrt[3]{4}$, and $r = \sqrt[3]{4} - 1 = 1.587 - 1 = 0.587$, so that $r = 58.7%$

# %% [markdown]
# In general, if we start with a quantity $P$ and increase it at a constant rate $r$ per unit of time, we will have after $n$ units of time the amount
#
# $$
# \begin{align*}
# A = P(1 + r)^n
# \end{align*}
# $$
#
# This is called the _compound-interest formula_.

# %% [markdown]
# ### Harmonic Mean

# %% [markdown]
# #### 3.39
# Find the harmonic mean $H$ of the numbers $3$, $5$, $6$, $6$, $7$, $10$, and $12$.

# %%
harmonic.mean <- function(s) {
    return (length(s)/sum(1/s))
}
s <- c(3, 5, 6, 6, 7, 10, 12)
round(harmonic.mean(s),2)
# Out:
# [1] 5.87

# %% [markdown]
# #### 3.40
# During four successive years, a home owner purchased oil for her furnace at respective costs of $\$0.80$, $\$0.90$, $\$1.05$, and $\$1.25$ per gallon (gal). What was the average cost of oil over the 4-year period?

# %%
# Case 1: The arithmetic mean if the home owner purchased the same quantity of oil each year
s <- c(.8, .9, 1.05, 1.25)
print(paste("The arithmetic mean of 1 gallon a year: ", mean(s), sep=""))
# Case 2: if The home owner spent the same amount each year
s*1000
# Out:
# [1] "The arithmetic mean of 1 gallon a year: 1"
# [1]  800  900 1050 1250

# %% [markdown]
# #### 3.44
# Find (a) the quartiles $Q_1$, $Q_2$, and $Q_3$ and (b) the deciles $D_1$, $D_2$,$\ldots$,$D_9$ for the wages of the $65$ employees at the P&R Comapny.

# %%
X <- wage.marks <- c( 255, 265, 275, 285, 295, 305, 315)
f <- number.of.employees <- c(8, 10, 16, 14, 10, 5, 2)
df <- data.frame(wage.marks, f)
N <- sum(f)
(Q1.mark <- N/4)
(Q2.mark <- N/4)
(Q3.mark <- 3*N/4)

# A
(Q1 <- 259.995 + 8.25/10*10)
(Q2 <- 269.995 + 14.5/16*10)
(Q3 <- 289.995 + 0.75/10*10)

# B
(D1 <- 249.995 + 6.5/8*10)
(D2 <- 259.995 + 5/10*10)
(D3 <- 269.995 + 1.5/16*10)
(D4 <- 279.995 + 8/16*10)
# Out:
# [1] 16.25
# [1] 16.25
# [1] 48.75
# [1] 268.245
# [1] 279.0575
# [1] 290.745
# [1] 258.12
# [1] 264.995
# [1] 270.9325
# [1] 284.995

# %% [markdown]
# ---

# %% [markdown]
# ## Quartiles, Deciles, and Percentiles

# %% [markdown]
# 44. Find (a) the quaritles $Q_1$, $Q_2$, and $Q_3$ and (b) the deciles $D_1$, $D_2$,$\ldots$,$D_9$ for the wages of the $65$ employees at the P&R Company.

# %% [markdown]
# The first quartile $Q_1$ is that wage obtained by counting $\frac{N}{4} = \frac{65}{4} = 16.25$ of the cases, beginning with the first (lowest) class. Since the first class contains $8$ cases, we must take $8.25(16.25 - 8)$ of the $10$ cases from the second class. Using the method of linear interpolation, we have
# $$
# \begin{align*}
# Q_1 = \$259.995 + \frac{8.25}{10}(\$10.00) = \$268.25
# \end{align*}
# $$
#
# The second quartile $Q_2$ is obtained by counting the first $\frac{2N}{4} = \frac{N}{2} = \frac{65}{2} = 32.5$ of the cases. Since the first two classes comprise $18$ cases, we must take $32.5 - 18 = 14.5$ of the $16$ cases from the third class; thus
# $$
# \begin{align*}
# Q_2 = \$269.995 + \frac{14.5}{16}(\$10.00) = \$279.06
# \end{align*}
# $$
#
# Note that $Q_2$ is actually the median.<p>
# The third quartile $Q_3$ is obtained by counting the first $\frac{3N}{4} = \frac{3}{4}(65) = 48.75$ of the cases. Since the first four classes comprise 48 cases, we must take $48.75 - 48 = 0.75$ of the $10$ cases from the fifth class; thus
# $$
# \begin{align*}
# Q_3 = \$289.995 + \frac{0.75}{10}(\$10.00) = \$290.75
# \end{align*}
# $$
#
# Hence $25\%$ of the employees earn $\$268.25$ or less, $50\%$ earn $\$279.06$ or less, and $75\%$ earn $\$290.75$ or less.

# %%
breaks <- seq(25000, 32000, by=1000)
f <- c(8, 10, 16, 14, 10, 5, 2)
s1 <- c()
for(i in 1:length(f)){
    s2 <- sample(breaks[i]:(breaks[i+1]-1), f[i], replace=TRUE)
    s1 <- sample(c(s1, s2))
    rm(s2)
}
s1 <- s1/100
breaks <- breaks/100
(pr.table <- table(cut(s1, breaks=breaks, right=FALSE)))
# Out:
# [250,260) [260,270) [270,280) [280,290) [290,300) [300,310) [310,320)
#         8        10        16        14        10         5         2

# %%
q.cases <- sum(f)/4
d.cases <- sum(f)/10
boundaries <- breaks - .005
divs<- boundaries[1:length(boundaries)]
freq <- c(0, as.vector(pr.table))
cum.sum <- cumsum(freq)
c(divs,freq)
Q.s <- c()
for(i in 1:4){
    q <- q.cases*i
    ind <- tail(which(cum.sum < q),1)
    q.left <- q - cum.sum[ind]
    q.sub <- round(divs[ind] + q.left/f[ind+1] * 10.00,2)
    Q.s <- c(Q.s, q.sub)
}
Q.s
D.s <- c()
for(i in 1:10){
    d <- d.cases*i
    ind <- tail(which(cum.sum < d),1)
    d.left <- d - cum.sum[ind]
    d.sub <- round(divs[ind] + d.left/f[ind+1] * 10.00,2)
    D.s <- c(D.s, d.sub)
}
D.s
# Out:
#  [1] 249.995 259.995 269.995 279.995 289.995 299.995 309.995 319.995   0.000
# [10]   8.000  10.000  16.000  14.000  10.000   5.000   2.000
# [1] 265.15 280.35 291.50     NA
#  [1] 256.50 263.12 271.07 275.71 280.35 285.00 291.50 298.00 302.50     NA

# %%
quantile(s1, prob=seq(0,1,length=6),type=5)
# Out:
#      0%     20%     40%     60%     80%    100%
# 250.400 264.430 274.490 282.965 294.305 314.430

# %% [markdown]
# ---

# %% [markdown]
# 46. The following data frame contains the per capita income for the 50 states. Find $Q_1, Q_2, Q_3,$ and $P95$. Also, give the states that are on both sides of those quaritles or percentiles.

# %%
state <- c(
    "Wyoming", "Montana", "North Dakota", "New Mexico", "West Virginia", "Rhode Island", "Virginia", "South Dakota", "Alabama", "Arkansas",
    "Maryland", "Iowa", "Nebraska", "Hawaii", "Mississippi", "Vermont", "Maine", "Oklahoma", "Delaware", "Alaska", "Tennessee", "Kansas",
    "Arizona", "Nevada", "Utah", "Pennsylvania", "Wisconsin", "Massachusetts", "Missouri", "Idaho", "Kentucky", "Minnesota", "Florida",
    "South Carolina", "New York", "Indiana", "Connecticut", "Ohio", "New Hampshire", "Texas", "Oregon", "New Jersey", "California", "Colorado",
    "North Carolina", "Illinois", "Michigan", "Washington", "Georgia", "Louisiana"
)
per.capita.income <- c(
    36778, 29387, 31395, 27664, 27215, 36153, 38390, 31614, 29136, 26874, 41760, 32315, 33616, 34539, 25318, 33327, 31252, 29330, 37065, 35612,
    31107, 32836, 30267, 35883, 28061, 34897, 33565, 44289, 31899, 28158, 28513, 37373, 33219, 28352, 40507, 31276, 47819, 32478, 38408, 32462,
    32103, 43771, 37036, 37946, 30553, 36120, 33116, 35409, 31121, 24820
)
p46.s1 <- data.frame(state,per.capita.income)

# %%
sorted.p46.s1 <- p46.s1[order(p46.s1$per.capita.income),]
(q1 <- (quantile(sorted.p46.s1$per.capita.income, 0.25)))
c(tail(sorted.p46.s1[sorted.p46.s1$per.capita.income < q1,], 1)$state, head(sorted.p46.s1[sorted.p46.s1$per.capita.income > q1,],1)$state)
(q2 <- quantile(sorted.p46.s1$per.capita.income, 0.50))
c(tail(sorted.p46.s1[sorted.p46.s1$per.capita.income < q2,], 1)$state, head(sorted.p46.s1[sorted.p46.s1$per.capita.income > q2,],1)$state)
(q3 <- quantile(sorted.p46.s1$per.capita.income, 0.75))
c(tail(sorted.p46.s1[sorted.p46.s1$per.capita.income < q3,], 1)$state, head(sorted.p46.s1[sorted.p46.s1$per.capita.income > q3,],1)$state)
(p95 <- quantile(sorted.p46.s1$per.capita.income, 0.95))
c(tail(sorted.p46.s1[sorted.p46.s1$per.capita.income < p95,], 1)$state, head(sorted.p46.s1[sorted.p46.s1$per.capita.income > p95,],1)$state)
# Out:
#     25%
# 30338.5
# [1] "Arizona"        "North Carolina"
#   50%
# 32657
# [1] "Ohio"   "Kansas"
#      75%
# 36144.75
# [1] "Illinois"     "Rhode Island"
#      95%
# 42866.05
# [1] "Maryland"   "New Jersey"
